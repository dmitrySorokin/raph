# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import sys
sys.path.append('..')

from nethack_raph.MonsterGlossary import MONSTERS_GLOSSARY

# %% [markdown]
# ## ARMOR

# %%
URL = 'https://nethackwiki.com/wiki/Armor'
response = requests.get(URL)
soup = BeautifulSoup(response.text,'html.parser')

tables = soup.find_all('table',{'class':'prettytable'})
tables
# Out:
# [<table class="prettytable">
#  <tbody><tr>
#  <th colspan="3"><b><a href="/wiki/Item" title="Item">Item</a> classes</b>
#  </th></tr>
#  <tr>
#  <td style="width: 50%;"><a href="/wiki/Amulet" title="Amulet"><span class="nhsym clr-cyan">"</span> Amulets</a>
#  </td>
#  <td style="width: 50%;"><a class="mw-selflink selflink"><span class="nhsym clr-cyan">[</span> Armor</a>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Comestible" title="Comestible"><span class="nhsym clr-brown">%</span> Comestibles</a>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/Coin" title="Coin"><span class="nhsym clr-yellow">$</span> Coins</a>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Gem" title="Gem"><span class="nhsym clr-lightgray">*</span> Gems</a>
#  </td>
#  <td><a href="/wiki/Potion" title="Potion"><span class="nhsym clr-green">!</span> Potions</a>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Ring" title="Ring"><span class="nhsym clr-red">=</span> Rings</a>
#  </td>
#  <td><a href="/wiki/Scroll" title="Scroll"><span class="nhsym clr-white">?</span> Scrolls</a>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Spellbook" title="Spellbook"><span class="nhsym clr-magenta">+</span> Spellbooks</a>
#  </td>
#  <td><a href="/wiki/Statue" title="Statue"><span class="nhsym clr-white">`</span> Statues</a>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Tool" title="Tool"><span class="nhsym clr-brown">(</span> Tools</a>
#  </td>
#  <td><a href="/wiki/Boulder" title="Boulder"><span class="nhsym clr-white">`</span> Boulders</a>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Weapon" title="Weapon"><span class="nhsym clr-brown">)</span> Weapons</a>
#  </td>
#  <td><a href="/wiki/Wand" title="Wand"><span class="nhsym clr-yellow">/</span> Wands</a>
#  </td></tr></tbody></table>,
#  <table class="prettytable">
#  <tbody><tr>
#  <th>Name
#  </th>
#  <th>Cost
#  </th>
#  <th>Weight
#  </th>
#  <th><a href="/wiki/Armor_class" title="Armor class">AC</a>
#  </th>
#  <th>Weight per<br/>AC (+0)
#  </th>
#  <th>Max AC<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup>
#  </th>
#  <th>Weight per<br/>max AC
#  </th>
#  <th>Material
#  </th>
#  <th>Effect
#  </th>
#  <th><a href="/wiki/Magic_cancellation" title="Magic cancellation">MC</a>
#  </th>
#  <th>Prob<sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup> (‰)
#  </th>
#  <th><a class="mw-redirect" href="/wiki/Magical_object" title="Magical object">Magical</a>
#  </th>
#  <th>Appearance
#  </th></tr>
#  <tr>
#  <td colspan="10"><b><a href="/wiki/Shirt" title="Shirt">Shirts</a></b>
#  </td></tr>
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Hawaiian_shirt" title="Hawaiian shirt">Hawaiian shirt</a></td>
#  <td>3</td>
#  <td>5</td>
#  <td>0</td>
#  <td>Infinite</td>
#  <td>5</td>
#  <td>1.0</td>
#  <td>cloth</td>
#  <td>Shop</td>
#  <td></td>
#  <td>8</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/T-shirt" title="T-shirt">T-shirt</a></td>
#  <td>2</td>
#  <td>5</td>
#  <td>0</td>
#  <td>Infinite</td>
#  <td>5</td>
#  <td>1.0</td>
#  <td>cloth</td>
#  <td>Shop</td>
#  <td></td>
#  <td>2</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td colspan="10"><a href="/wiki/Body_armor" title="Body armor"><b>Suits</b></a>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/
td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Crystal_plate_mail" title="Crystal plate mail">crystal plate mail</a></td>
#  <td>820</td>
#  <td>450</td>
#  <td>7</td>
#  <td>64</td>
#  <td>12</td>
#  <td>38</td>
#  <td>glass</td>
#  <td></td>
#  <td>2</td>
#  <td>10</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td colspan="10"><a href="/wiki/Dragon_scale_mail" title="Dragon scale mail"><b>Dragon suits</b></a>
#  </td></tr>
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Dragon_scales" title="Dragon scales">dragon scales</a></td>
#  <td>500</td>
#  <td>40</td>
#  <td>3</td>
#  <td>13</td>
#  <td>8</td>
#  <td>5.0</td>
#  <td>dragon</td>
#  <td>Resist<sup>%</sup></td>
#  <td></td>
#  <td>--</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Dragon_scale_mail" title="Dragon scale mail">dragon scale mail</a></td>
#  <td>900</td>
#  <td>40</td>
#  <td>9</td>
#  <td>4.4</td>
#  <td>14</td>
#  <td>2.9</td>
#  <td>dragon</td>
#  <td>Resist<sup>%</sup></td>
#  <td></td>
#  <td>--</td>
#  <td>Yes</td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td colspan="10"><b><a href="/wiki/Cloak" title="Cloak">Cloaks</a></b>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Mummy_wrapping" title="Mummy wrapping">mummy wrapping</a></td>
#  <td>2</td>
#  <td>3</td>
#  <td>0</td>
#  <td>Infinite</td>
#  <td>5</td>
#  <td>0.60</td>
#  <td>cloth</td>
#  <td>Vis</td>
#  <td>1</td>
#  <td>--</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Orcish_cloak" title="Orcish cloak">orcish cloak</a></td>
#  <td>40</td>
#  <td>10</td>
#  <td>0</td>
#  <td>Infinite</td>
#  <td>5</td>
#  <td>2.0</td>
#  <td>cloth</td>
#  <td></td>
#  <td>1</td>
#  <td>8</td>
#  <td></td>
#  <td>coarse mantelet
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Dwarvish_cloak" title="Dwarvish cloak">dwarvish cloak</a></td>
#  <td>50</td>
#  <td>10</td>
#  <td>0</td>
#  <td>Infinite</td>
#  <td>5</td>
#  <td>2.0</td>
#  <td>cloth</td>
#  <td></td>
#  <td>1</td>
#  <td>8</td>
#  <td></td>
#  <td>hooded cloak
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Leather_cloak" title="Leather cloak">leather cloak</a></td>
#  <td>40</td>
#  <td>15</td>
#  <td>1</td>
#  <td>15</td>
#  <td>6</td>
#  <td>2.5</td>
#  <td>leather</td>
#  <td></td>
#  <td>1</td>
#  <td>8</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Cloak_of_displacement" title="Cloak of displacement">cloak of displacement</a></td>
#  <td>50</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>cloth</td>
#  <td>Displ</td>
#  <td>1</td>
#  <td>10</td>
#  <td>Yes</td>
#  <td>*piece of cloth
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Oilskin_cloak" title="Oilskin cloak">oilskin cloak</a></td>
#  <td>50</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>cloth</td>
#  <td>Water</td>
#  <td>2</td>
#  <td>8</td>
#  <td></td>
#  <td>slippery cloak
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Alchemy_smock" title="Alchemy smock">alchemy smock</a></td>
#  <td>50</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>cloth</td>
#  <td>Poi+Acd</td>
#  <td>1</td>
#  <td>9</td>
#  <td>Yes</td>
#  <td>apron
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Cloak_of_invisibility" title="Cloak of invisibility">cloak of invisibility</a></td>
#  <td>60</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>cloth</td>
#  <td>Invis</td>
#  <td>1</td>
#  <td>10</td>
#  <td>Yes</td>
#  <td>*opera cloak
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Cloak_of_magic_resistance" title="Cloak of magic resistance">cloak of magic resistance</a></td>
#  <td>60</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>cloth</td>
#  <td>Magic</td>
#  <td>1</td>
#  <td>2</td>
#  <td>Yes</td>
#  <td>*ornamental cope
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Elven_cloak" title="Elven cloak">elven cloak</a></td>
#  <td>60</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>8</td>
#  <td>1.3</td>
#  <td>cloth</td>
#  <td>Stealth</td>
#  <td>1</td>
#  <td>8</td>
#  <td>Yes</td>
#  <td>faded pall
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Robe" title="Robe">robe</a></td>
#  <td>50</td>
#  <td>15</td>
#  <td>2</td>
#  <td>7.5</td>
#  <td>7</td>
#  <td>2.1</td>
#  <td>cloth</td>
#  <td>Spell<sup>1</sup></td>
#  <td>2</td>
#  <td>3</td>
#  <td>Yes</td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Cloak_of_protection" title="Cloak of protection">cloak of protection</a></td>
#  <td>50</td>
#  <td>10</td>
#  <td>3</td>
#  <td>3.3</td>
#  <td>8</td>
#  <td>1.3</td>
#  <td>cloth</td>
#  <td>Prot</td>
#  <td>3</td>
#  <td>9</td>
#  <td>Yes</td>
#  <td>*tattered cape
#  </td></tr>
#  <tr>
#  <td colspan="10"><b><a href="/wiki/Helm" title="Helm">Helms</a></b>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Fedora" title="Fedora">fedora</a></td>
#  <td>1</td>
#  <td>3</td>
#  <td>0</td>
#  <td>Infinite</td>
#  <td>5</td>
#  <td>0.60</td>
#  <td>cloth</td>
#  <td></td>
#  <td></td>
#  <td>--</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Dunce_cap" title="Dunce cap">dunce cap</a></td>
#  <td>1</td>
#  <td>4</td>
#  <td>0</td>
#  <td>Infinite</td>
#  <td>5</td>
#  <td>0.80</td>
#  <td>cloth</td>
#  <td>Stupid</td>
#  <td></td>
#  <td>3</td>
#  <td>Yes</td>
#  <td>conical hat
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Cornuthaum" title="Cornuthaum">cornuthaum</a></td>
#  <td>80</td>
#  <td>4</td>
#  <td>0</td>
#  <td>Infinite</td>
#  <td>7 wizard,<br/>5 others</td>
#  <td>0.57 wizard,<br/>0.80 others</td>
#  <td>cloth</td>
#  <td>Clair</td>
#  <td>1</td>
#  <td>3</td>
#  <td>Yes</td>
#  <td>conical hat
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Dented_pot" title="Dented pot">dented pot</a></td>
#  <td>8</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>2</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Elven_leather_helm" title="Elven leather helm">elven leather helm</a></td>
#  <td>8</td>
#  <td>3</td>
#  <td>1</td>
#  <td>3.0</td>
#  <td>8</td>
#  <td>0.38</td>
#  <td>leather</td>
#  <td></td>
#  <td></td>
#  <td>6</td>
#  <td></td>
#  <td>leather hat
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Helmet" title="Helmet">helmet (kabuto)</a></td>
#  <td>10</td>
#  <td>30</td>
#  <td>1</td>
#  <td>30</td>
#  <td>6</td>
#  <td>5.0</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>10</td>
#  <td></td>
#  <td>*plumed helmet
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Orcish_helm" title="Orcish helm">orcish helm</a></td>
#  <td>10</td>
#  <td>30</td>
#  <td>1</td>
#  <td>30</td>
#  <td>6</td>
#  <td>5.0</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>6</td>
#  <td></td>
#  <td>iron skull cap
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Helm_of_brilliance" title="Helm of brilliance">helm of brilliance</a></td>
#  <td>50</td>
#  <td>50</td>
#  <td>1</td>
#  <td>50</td>
#  <td>6</td>
#  <td>8.3</td>
#  <td>iron</td>
#  <td>Int+Wis</td>
#  <td></td>
#  <td>6</td>
#  <td>Yes</td>
#  <td>*etched helmet
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Helm_of_opposite_alignment" title="Helm of opposite alignment">helm of opposite alignment</a></td>
#  <td>50</td>
#  <td>50</td>
#  <td>1</td>
#  <td>50</td>
#  <td>6</td>
#  <td>8.3</td>
#  <td>iron</td>
#  <td>Align</td>
#  <td></td>
#  <td>6</td>
#  <td>Yes</td>
#  <td>*crested helmet
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Helm_of_telepathy" title="Helm of telepathy">helm of telepathy</a></td>
#  <td>50</td>
#  <td>50</td>
#  <td>1</td>
#  <td>50</td>
#  <td>6</td>
#  <td>8.3</td>
#  <td>iron</td>
#  <td>ESP</td>
#  <td></td>
#  <td>2</td>
#  <td>Yes</td>
#  <td>*visored helmet
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Dwarvish_iron_helm" title="Dwarvish iron helm">dwarvish iron helm</a></td>
#  <td>20</td>
#  <td>40</td>
#  <td>2</td>
#  <td>20</td>
#  <td>7</td>
#  <td>5.7</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>6</td>
#  <td></td>
#  <td>hard hat
#  </td></tr>
#  <tr>
#  <td colspan="10"><b><a href="/wiki/Gloves" title="Gloves">Gloves</a></b>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Leather_gloves" title="Leather gloves">leather gloves (yugake)</a></td>
#  <td>8</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>leather</td>
#  <td></td>
#  <td></td>
#  <td>16</td>
#  <td></td>
#  <td>*old gloves
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Gauntlets_of_dexterity" title="Gauntlets of dexterity">gauntlets of dexterity</a></td>
#  <td>50</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>leather</td>
#  <td>Dex</td>
#  <td></td>
#  <td>8</td>
#  <td>Yes</td>
#  <td>*padded gloves
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Gauntlets_of_fumbling" title="Gauntlets of fumbling">gauntlets of fumbling</a></td>
#  <td>50</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>leather</td>
#  <td>Fumble</td>
#  <td></td>
#  <td>8</td>
#  <td>Yes</td>
#  <td>*riding gloves
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Gauntlets_of_power" title="Gauntlets of power">gauntlets of power</a></td>
#  <td>50</td>
#  <td>30</td>
#  <td>1</td>
#  <td>30</td>
#  <td>6</td>
#  <td>5.0</td>
#  <td>iron</td>
#  <td>Str</td>
#  <td></td>
#  <td>8</td>
#  <td>Yes</td>
#  <td>*fencing gloves
#  </td></tr>
#  <tr>
#  <td colspan="10"><b><a href="/wiki/Shield" title="Shield">Shields</a></b>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Small_shield" title="Small shield">small shield</a></td>
#  <td>3</td>
#  <td>30</td>
#  <td>1</td>
#  <td>30</td>
#  <td>6</td>
#  <td>5.0</td>
#  <td>wood</td>
#  <td>Spell<sup>2</sup></td>
#  <td></td>
#  <td>6</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Orcish_shield" title="Orcish shield">orcish shield</a></td>
#  <td>7</td>
#  <td>50</td>
#  <td>1</td>
#  <td>50</td>
#  <td>6</td>
#  <td>8.3</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>2</td>
#  <td></td>
#  <td>red-eyed
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Uruk-hai_shield" title="Uruk-hai shield">Uruk-hai shield</a></td>
#  <td>7</td>
#  <td>50</td>
#  <td>1</td>
#  <td>50</td>
#  <td>6</td>
#  <td>8.3</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>2</td>
#  <td></td>
#  <td>white-handed
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Elven_shield" title="Elven shield">elven shield</a></td>
#  <td>7</td>
#  <td>40</td>
#  <td>2</td>
#  <td>20</td>
#  <td>9</td>
#  <td>4.4</td>
#  <td>wood</td>
#  <td></td>
#  <td></td>
#  <td>2</td>
#  <td></td>
#  <td>blue and green
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Dwarvish_roundshield" title="Dwarvish roundshield">dwarvish roundshield</a></td>
#  <td>10</td>
#  <td>100</td>
#  <td>2</td>
#  <td>50</td>
#  <td>7</td>
#  <td>14</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>4</td>
#  <td></td>
#  <td>large round
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Large_shield" title="Large shield">large shield</a></td>
#  <td>10</td>
#  <td>100</td>
#  <td>2</td>
#  <td>50</td>
#  <td>7</td>
#  <td>14</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>7</td>
#  <td></td>
#  <td>--
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Shield_of_reflection" title="Shield of reflection">shield of reflection</a></td>
#  <td>50</td>
#  <td>50</td>
#  <td>2</td>
#  <td>25</td>
#  <td>7</td>
#  <td>7.1</td>
#  <td>silver</td>
#  <td>Reflect</td>
#  <td></td>
#  <td>3</td>
#  <td>Yes</td>
#  <td>polished silver
#  </td></tr>
#  <tr>
#  <td colspan="10"><b><a href="/wiki/Boots" title="Boots">Boots</a></b>
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Low_boots" title="Low boots">low boots</a></td>
#  <td>8</td>
#  <td>10</td>
#  <td>1</td>
#  <td>10</td>
#  <td>6</td>
#  <td>1.7</td>
#  <td>leather</td>
#  <td></td>
#  <td></td>
#  <td>25</td>
#  <td></td>
#  <td>walking shoes
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Elven_boots" title="Elven boots">elven boots</a></td>
#  <td>8</td>
#  <td>15</td>
#  <td>1</td>
#  <td>15</td>
#  <td>8</td>
#  <td>1.9</td>
#  <td>leather</td>
#  <td>Stealth</td>
#  <td></td>
#  <td>12</td>
#  <td>Yes</td>
#  <td>*mud boots
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Kicking_boots" title="Kicking boots">kicking boots</a></td>
#  <td>8</td>
#  <td>50</td>
#  <td>1</td>
#  <td>50</td>
#  <td>6</td>
#  <td>8.3</td>
#  <td>iron</td>
#  <td>Kick</td>
#  <td></td>
#  <td>12</td>
#  <td>Yes</td>
#  <td>*buckled boots
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Fumble_boots" title="Fumble boots">fumble boots</a></td>
#  <td>30</td>
#  <td>20</td>
#  <td>1</td>
#  <td>20</td>
#  <td>6</td>
#  <td>3.3</td>
#  <td>leather</td>
#  <td>Fumble</td>
#  <td></td>
#  <td>12</td>
#  <td>Yes</td>
#  <td>*riding boots
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Levitation_boots" title="Levitation boots">levitation boots</a></td>
#  <td>30</td>
#  <td>15</td>
#  <td>1</td>
#  <td>15</td>
#  <td>6</td>
#  <td>2.5</td>
#  <td>leather</td>
#  <td>Lev</td>
#  <td></td>
#  <td>12</td>
#  <td>Yes</td>
#  <td>*snow boots
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Jumping_boots" title="Jumping boots">jumping boots</a></td>
#  <td>50</td>
#  <td>20</td>
#  <td>1</td>
#  <td>20</td>
#  <td>6</td>
#  <td>3.3</td>
#  <td>leather</td>
#  <td>Jump</td>
#  <td></td>
#  <td>12</td>
#  <td>Yes</td>
#  <td>*hiking boots
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Speed_boots" title="Speed boots">speed boots</a></td>
#  <td>50</td>
#  <td>20</td>
#  <td>1</td>
#  <td>20</td>
#  <td>6</td>
#  <td>3.3</td>
#  <td>leather</td>
#  <td>Speed</td>
#  <td></td>
#  <td>12</td>
#  <td>Yes</td>
#  <td>*combat boots
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Water_walking_boots" title="Water walking boots">water walking boots</a></td>
#  <td>50</td>
#  <td>20</td>
#  <td>1</td>
#  <td>20</td>
#  <td>6</td>
#  <td>3.3</td>
#  <td>leather</td>
#  <td>WWalk</td>
#  <td></td>
#  <td>12</td>
#  <td>Yes</td>
#  <td>*jungle boots
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/High_boots" title="High boots">high boots</a></td>
#  <td>12</td>
#  <td>20</td>
#  <td>2</td>
#  <td>10</td>
#  <td>7</td>
#  <td>2.9</td>
#  <td>leather</td>
#  <td></td>
#  <td></td>
#  <td>15</td>
#  <td></td>
#  <td>jackboots
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Iron_shoes" title="Iron shoes">iron shoes</a></td>
#  <td>16</td>
#  <td>50</td>
#  <td>2</td>
#  <td>25</td>
#  <td>7</td>
#  <td>7.1</td>
#  <td>iron</td>
#  <td></td>
#  <td></td>
#  <td>7</td>
#  <td></td>
#  <td>hard shoes
#  </td></tr></tbody></table>,
#  <table class="prettytable">
#  <tbody><tr>
#  <th>Material</th>
#  <th>Erosion</th>
#  <th>Hinders spellcasting?
#  </th></tr>
#  <tr>
#  <td>bronze</td>
#  <td>corroded</td>
#  <td>yes
#  </td></tr>
#  <tr>
#  <td>cloth</td>
#  <td>burnt, rotten</td>
#  <td>no
#  </td></tr>
#  <tr>
#  <td>dragon hide</td>
#  <td>-</td>
#  <td>no
#  </td></tr>
#  <tr>
#  <td>glass</td>
#  <td>-</td>
#  <td>no
#  </td></tr>
#  <tr>
#  <td>iron</td>
#  <td>rusty, corroded</td>
#  <td>yes
#  </td></tr>
#  <tr>
#  <td>leather</td>
#  <td>burnt, rotten</td>
#  <td>no
#  </td></tr>
#  <tr>
#  <td>mithril</td>
#  <td>-</td>
#  <td>yes
#  </td></tr>
#  <tr>
#  <td>silver</td>
#  <td>-</td>
#  <td>yes
#  </td></tr>
#  <tr>
#  <td>wood</td>
#  <td>burnt, rotten</td>
#  <td>no
#  </td></tr></tbody></table>,
#  <table class="prettytable">
#  <tbody><tr>
#  <td>Acd</td>
#  <td>Gives <a href="/wiki/Acid_resistance" title="Acid resistance">acid resistance</a>.
#  </td></tr>
#  <tr>
#  <td>Align</td>
#  <td>Changes your alignment, removes protection, and auto-curses.
#  </td></tr>
#  <tr>
#  <td>Clair</td>
#  <td>A <a href="/wiki/Wizard" title="Wizard">wizard</a> gets <a href="/wiki/Clairvoyance" title="Clairvoyance">clairvoyance</a> and +1 <a class="mw-redirect" href="/wiki/Charisma" title="Charisma">charisma</a>, but other characters have existing clairvoyance blocked and get -1 charisma.
#  </td></tr>
#  <tr>
#  <td>Dex</td>
#  <td>Adds armor's enchantment to your <a href="/wiki/Dexterity" title="Dexterity">dexterity</a>.
#  </td></tr>
#  <tr>
#  <td>Displ</td>
#  <td>Gives <a href="/wiki/Displacement" title="Displacement">displacement</a>.
#  </td></tr>
#  <tr>
#  <td>ESP</td>
#  <td>Gives <a href="/wiki/Telepathy" title="Telepathy">telepathy</a>.
#  </td></tr>
#  <tr>
#  <td>Fumble</td>
#  <td>You will occasionally <a class="mw-redirect" href="/wiki/Fumble" title="Fumble">fumble</a>.
#  </td></tr>
#  <tr>
#  <td>Int+Wis</td>
#  <td>Adds armor's enchantment to your intelligence and wisdom.
#  </td></tr>
#  <tr>
#  <td>Invis</td>
#  <td>Gives <a href="/wiki/Invisibility" title="Invisibility">invisibility</a>.
#  </td></tr>
#  <tr>
#  <td>Jump</td>
#  <td>Gives <a href="/wiki/Jumping" title="Jumping">jumping</a> at will. The special restrictions for Knights do not apply while this item is worn.
#  </td></tr>
#  <tr>
#  <td>Kick</td>
#  <td>Kicking does additional damage, and grants martial arts bonuses.
#  </td></tr>
#  <tr>
#  <td>Lev</td>
#  <td>Causes <a href="/wiki/Levitation" title="Levitation">levitation</a>. Does NOT prevent you being drowned by monsters.
#  </td></tr>
#  <tr>
#  <td>Magic</td>
#  <td>Gives <a href="/wiki/Magic_resistance" title="Magic resistance">magic resistance</a>. Does NOT affect magic cancellation.
#  </td></tr>
#  <tr>
#  <td>Poison</td>
#  <td>Gives <a href="/wiki/Poison_resistance" title="Poison resistance">poison resistance</a>.
#  </td></tr>
#  <tr>
#  <td>Reflect</td>
#  <td>Gives <a href="/wiki/Reflection" title="Reflection">reflection</a>.
#  </td></tr>
#  <tr>
#  <td>Resist<sup>%</sup></td>
#  <td><a href="/wiki/Dragon" title="Dragon">Dragon</a> scales provide resistance according to the color of the dragon:
#  <ul><li>red = <a href="/wiki/Fire_resistance" title="Fire resistance">fire resistance</a>,</li>
#  <li>white = <a href="/wiki/Cold_resistance" title="Cold resistance">cold resistance</a>,</li>
#  <li>orange = <a href="/wiki/Sleep_resistance" title="Sleep resistance">sleep resistance</a>,</li>
#  <li>blue = <a href="/wiki/Shock_resistance" title="Shock resistance">shock resistance</a>,</li>
#  <li>green = <a href="/wiki/Poison_resistance" title="Poison resistance">poison resistance</a>,</li>
#  <li>yellow = <a href="/wiki/Acid_resistance" title="Acid resistance">acid resistance</a>,</li>
#  <li>black = <a href="/wiki/Disintegration_resistance" title="Disintegration resistance">disintegration resistance</a>,</li>
#  <li>silver = <a href="/wiki/Reflection" title="Reflection">reflection</a>,</li>
#  <li>gray = <a href="/wiki/Magic_resistance" title="Magic resistance">magic resistance</a></li></ul>
#  </td></tr>
#  <tr>
#  <td>Shop</td>
#  <td>If not covered by body armor or cloak, shopkeepers buy and sell at the same rate as inexperienced (level &lt; 15) tourists (buy at 1/3 of and sell at 4/3 of the normal price).
#  </td></tr>
#  <tr>
#  <td>Sleep</td>
#  <td>Gives <a href="/wiki/Sleep_resistance" title="Sleep resistance">sleep resistance</a>.
#  </td></tr>
#  <tr>
#  <td>Speed</td>
#  <td>Gives you the <a href="/wiki/Speed" title="Speed">speed</a> extrinsic, the same as a <a href="/wiki/Potion_of_speed" title="Potion of speed">potion of speed</a> or spell of <a href="/wiki/Haste_self" title="Haste self">haste self</a>.
#  </td></tr>
#  <tr>
#  <td>Spell<sup>1</sup></td>
#  <td>Player <a href="/wiki/Spellcasting" title="Spellcasting">spellcasting</a> is more likely to succeed, and reduces the penalty for metallic armor.
#  </td></tr>
#  <tr>
#  <td>Spell<sup>2</sup></td>
#  <td>Does not limit <a href="/wiki/Spellcasting" title="Spellcasting">spellcasting</a> as much as other shields.
#  </td></tr>
#  <tr>
#  <td>Stealth</td>
#  <td>Gives <a href="/wiki/Stealth" title="Stealth">stealth</a>.
#  </td></tr>
#  <tr>
#  <td>Str</td>
#  <td>Increases your <a href="/wiki/Strength" title="Strength">strength</a> to 25.
#  </td></tr>
#  <tr>
#  <td>Stupid</td>
#  <td>Your <a class="mw-redirect" href="/wiki/Intelligence" title="Intelligence">intelligence</a> and <a href="/wiki/Wisdom" title="Wisdom">wisdom</a> are fixed at 6; auto-curses; shopkeepers buy and sell at the inexperienced Tourist rate.
#  </td></tr>
#  <tr>
#  <td>Vis</td>
#  <td>Overrides invisibility so you are again visible.
#  </td></tr>
#  <tr>
#  <td>Water</td>
#  <td>Protects metal body armor from rusting/corroding (1/3 chance of protection if cursed) and prevents grabbing attacks.
#  </td></tr>
#  <tr>
#  <td>WWalk</td>
#  <td>Allows you to walk on water. Does NOT prevent you being drowned by monsters.
#  </td></tr></tbody></table>]

# %%
table = tables[1]

# %%
rows = table.find_all('tr')
# columns = [v.text.replace('\n','') for v in rows[0].find_all('th')]

columns = ['name',
 'cost',
 'weight',
 'AC',
 'Weight perAC (+0)',
 'max_AC',
 'Weight permax AC',
 'material',
 'effect',
 'MC',
 'probability',
 'magical',
 'appearance',
 'armor_type']

df = pd.DataFrame(columns=columns)
df

for i in range(1,len(rows)):
    tds = rows[i].find_all('td')
    values = [td.text.replace('\n',''.replace('\xa0','')) for td in tds]
    if len(values) == 1:
        armor_type = values[0].lower()
    
    else:
        values += [armor_type]
        df = df.append(pd.Series(values, index=columns), ignore_index=True)

df['magical'] = df['magical'] == 'Yes'
df['appearance'] = [x.replace('*','').replace('--','') for x in df['appearance']]

df = df[df['name'] != 'cornuthaum']

df.loc[df['appearance'] != '', 'name'] = df['appearance']
df.drop(columns = ['Weight perAC (+0)','Weight permax AC', 'appearance'], inplace=True)
df[['AC', 'max_AC', 'cost', 'weight']] = df[['AC', 'max_AC', 'cost', 'weight']].astype(int)
df
# Out:
#                name  cost  weight  AC  max_AC material effect MC probability  \
# 0    Hawaiian shirt     3       5   0       5    cloth   Shop              8
# 1           T-shirt     2       5   0       5    cloth   Shop              2
# 2    leather jacket    10      30   1       6  leather                    12
# 3     leather armor     5     150   2       7  leather         1          82
# 4   crude ring mail    80     250   2       7     iron         1          20
# ..              ...   ...     ...  ..     ...      ...    ... ..         ...
# 58     hiking boots    50      20   1       6  leather   Jump             12
# 59     combat boots    50      20   1       6  leather  Speed             12
# 60     jungle boots    50      20   1       6  leather  WWalk             12
# 61        jackboots    12      20   2       7  leather                    15
# 62       hard shoes    16      50   2       7     iron                     7
#
#     magical armor_type
# 0     False     shirts
# 1     False     shirts
# 2     False      suits
# 3     False      suits
# 4     False      suits
# ..      ...        ...
# 58     True      boots
# 59     True      boots
# 60     True      boots
# 61    False      boots
# 62    False      boots
#
# [62 rows x 11 columns]

# %%
data = df.set_index('name').to_dict('index')
data
# Out:
# {'Hawaiian shirt': {'cost': 3,
#   'weight': 5,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Shop',
#   'MC': '',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'shirts'},
#  'T-shirt': {'cost': 2,
#   'weight': 5,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Shop',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'shirts'},
#  'leather jacket': {'cost': 10,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '12',
#   'magical': False,
#   'armor_type': 'suits'},
#  'leather armor': {'cost': 5,
#   'weight': 150,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'leather',
#   'effect': '',
#   'MC': '1',
#   'probability': '82',
#   'magical': False,
#   'armor_type': 'suits'},
#  'crude ring mail': {'cost': 80,
#   'weight': 250,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '20',
#   'magical': False,
#   'armor_type': 'suits'},
#  'studded leather armor': {'cost': 15,
#   'weight': 200,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'leather',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  'ring mail': {'cost': 100,
#   'weight': 250,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  'scale mail': {'cost': 45,
#   'weight': 250,
#   'AC': 4,
#   'max_AC': 9,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  'crude chain mail': {'cost': 75,
#   'weight': 300,
#   'AC': 4,
#   'max_AC': 9,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '20',
#   'magical': False,
#   'armor_type': 'suits'},
#  'chain mail': {'cost': 75,
#   'weight': 300,
#   'AC': 5,
#   'max_AC': 10,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  'elven mithril-coat': {'cost': 240,
#   'weight': 150,
#   'AC': 5,
#   'max_AC': 12,
#   'material': 'mithril',
#   'effect': '',
#   'MC': '2',
#   'probability': '15',
#   'magical': False,
#   'armor_type': 'suits'},
#  'splint mail': {'cost': 80,
#   'weight': 400,
#   'AC': 6,
#   'max_AC': 11,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '62',
#   'magical': False,
#   'armor_type': 'suits'},
#  'banded mail': {'cost': 90,
#   'weight': 350,
#   'AC': 6,
#   'max_AC': 11,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  'dwarvish mithril-coat': {'cost': 240,
#   'weight': 150,
#   'AC': 6,
#   'max_AC': 11,
#   'material': 'mithril',
#   'effect': '',
#   'MC': '2',
#   'probability': '10',
#   'magical': False,
#   'armor_type': 'suits'},
#  'bronze plate mail': {'cost': 400,
#   'weight': 450,
#   'AC': 6,
#   'max_AC': 11,
#   'material': 'copper',
#   'effect': '',
#   'MC': '1',
#   'probability': '25',
#   'magical': False,
#   'armor_type': 'suits'},
#  'plate mail (tanko)': {'cost': 600,
#   'weight': 450,
#   'AC': 7,
#   'max_AC': 12,
#   'material': 'iron',
#   'effect': '',
#   'MC': '2',
#   'probability': '44',
#   'magical': False,
#   'armor_type': 'suits'},
#  'crystal plate mail': {'cost': 820,
#   'weight': 450,
#   'AC': 7,
#   'max_AC': 12,
#   'material': 'glass',
#   'effect': '',
#   'MC': '2',
#   'probability': '10',
#   'magical': False,
#   'armor_type': 'suits'},
#  'dragon scales': {'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  'dragon scale mail': {'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  'mummy wrapping': {'cost': 2,
#   'weight': 3,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Vis',
#   'MC': '1',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  'coarse mantelet': {'cost': 40,
#   'weight': 10,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': '',
#   'MC': '1',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  'hooded cloak': {'cost': 50,
#   'weight': 10,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': '',
#   'MC': '1',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  'leather cloak': {'cost': 40,
#   'weight': 15,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': '',
#   'MC': '1',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  'piece of cloth': {'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Displ',
#   'MC': '1',
#   'probability': '10',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  'slippery cloak': {'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Water',
#   'MC': '2',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  'apron': {'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Poi+Acd',
#   'MC': '1',
#   'probability': '9',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  'opera cloak': {'cost': 60,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Invis',
#   'MC': '1',
#   'probability': '10',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  'ornamental cope': {'cost': 60,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Magic',
#   'MC': '1',
#   'probability': '2',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  'faded pall': {'cost': 60,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 8,
#   'material': 'cloth',
#   'effect': 'Stealth',
#   'MC': '1',
#   'probability': '8',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  'robe': {'cost': 50,
#   'weight': 15,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'cloth',
#   'effect': 'Spell1',
#   'MC': '2',
#   'probability': '3',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  'tattered cape': {'cost': 50,
#   'weight': 10,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'cloth',
#   'effect': 'Prot',
#   'MC': '3',
#   'probability': '9',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  'fedora': {'cost': 1,
#   'weight': 3,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': '',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'helms'},
#  'conical hat': {'cost': 1,
#   'weight': 4,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Stupid',
#   'MC': '',
#   'probability': '3',
#   'magical': True,
#   'armor_type': 'helms'},
#  'dented pot': {'cost': 8,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'helms'},
#  'leather hat': {'cost': 8,
#   'weight': 3,
#   'AC': 1,
#   'max_AC': 8,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '6',
#   'magical': False,
#   'armor_type': 'helms'},
#  'plumed helmet': {'cost': 10,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '10',
#   'magical': False,
#   'armor_type': 'helms'},
#  'iron skull cap': {'cost': 10,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '6',
#   'magical': False,
#   'armor_type': 'helms'},
#  'etched helmet': {'cost': 50,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'Int+Wis',
#   'MC': '',
#   'probability': '6',
#   'magical': True,
#   'armor_type': 'helms'},
#  'crested helmet': {'cost': 50,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'Align',
#   'MC': '',
#   'probability': '6',
#   'magical': True,
#   'armor_type': 'helms'},
#  'visored helmet': {'cost': 50,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'ESP',
#   'MC': '',
#   'probability': '2',
#   'magical': True,
#   'armor_type': 'helms'},
#  'hard hat': {'cost': 20,
#   'weight': 40,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '6',
#   'magical': False,
#   'armor_type': 'helms'},
#  'old gloves': {'cost': 8,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '16',
#   'magical': False,
#   'armor_type': 'gloves'},
#  'padded gloves': {'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Dex',
#   'MC': '',
#   'probability': '8',
#   'magical': True,
#   'armor_type': 'gloves'},
#  'riding gloves': {'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Fumble',
#   'MC': '',
#   'probability': '8',
#   'magical': True,
#   'armor_type': 'gloves'},
#  'fencing gloves': {'cost': 50,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'Str',
#   'MC': '',
#   'probability': '8',
#   'magical': True,
#   'armor_type': 'gloves'},
#  'small shield': {'cost': 3,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'wood',
#   'effect': 'Spell2',
#   'MC': '',
#   'probability': '6',
#   'magical': False,
#   'armor_type': 'shields'},
#  'red-eyed': {'cost': 7,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'shields'},
#  'white-handed': {'cost': 7,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'shields'},
#  'blue and green': {'cost': 7,
#   'weight': 40,
#   'AC': 2,
#   'max_AC': 9,
#   'material': 'wood',
#   'effect': '',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'shields'},
#  'large round': {'cost': 10,
#   'weight': 100,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '4',
#   'magical': False,
#   'armor_type': 'shields'},
#  'large shield': {'cost': 10,
#   'weight': 100,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '7',
#   'magical': False,
#   'armor_type': 'shields'},
#  'polished silver': {'cost': 50,
#   'weight': 50,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'silver',
#   'effect': 'Reflect',
#   'MC': '',
#   'probability': '3',
#   'magical': True,
#   'armor_type': 'shields'},
#  'walking shoes': {'cost': 8,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '25',
#   'magical': False,
#   'armor_type': 'boots'},
#  'mud boots': {'cost': 8,
#   'weight': 15,
#   'AC': 1,
#   'max_AC': 8,
#   'material': 'leather',
#   'effect': 'Stealth',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  'buckled boots': {'cost': 8,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'Kick',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  'riding boots': {'cost': 30,
#   'weight': 20,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Fumble',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  'snow boots': {'cost': 30,
#   'weight': 15,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Lev',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  'hiking boots': {'cost': 50,
#   'weight': 20,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Jump',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  'combat boots': {'cost': 50,
#   'weight': 20,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Speed',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  'jungle boots': {'cost': 50,
#   'weight': 20,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'WWalk',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  'jackboots': {'cost': 12,
#   'weight': 20,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '15',
#   'magical': False,
#   'armor_type': 'boots'},
#  'hard shoes': {'cost': 16,
#   'weight': 50,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '7',
#   'magical': False,
#   'armor_type': 'boots'}}

# %%
armor_glossary = """
Glyph 1977 Type: GLYPH_OBJ : ARMOR_CLASS: "leather hat"
Glyph 1978 Type: GLYPH_OBJ : ARMOR_CLASS: "iron skull cap"
Glyph 1979 Type: GLYPH_OBJ : ARMOR_CLASS: "hard hat"
Glyph 1980 Type: GLYPH_OBJ : ARMOR_CLASS: "fedora"
Glyph 1981 Type: GLYPH_OBJ : ARMOR_CLASS: "conical hat"
Glyph 1982 Type: GLYPH_OBJ : ARMOR_CLASS: "conical hat"
Glyph 1983 Type: GLYPH_OBJ : ARMOR_CLASS: "dented pot"
Glyph 1984 Type: GLYPH_OBJ : ARMOR_CLASS: "plumed helmet"
Glyph 1985 Type: GLYPH_OBJ : ARMOR_CLASS: "etched helmet"
Glyph 1986 Type: GLYPH_OBJ : ARMOR_CLASS: "crested helmet"
Glyph 1987 Type: GLYPH_OBJ : ARMOR_CLASS: "visored helmet"
Glyph 1988 Type: GLYPH_OBJ : ARMOR_CLASS: "gray dragon scale mail"
Glyph 1989 Type: GLYPH_OBJ : ARMOR_CLASS: "silver dragon scale mail"
Glyph 1990 Type: GLYPH_OBJ : ARMOR_CLASS: "red dragon scale mail"
Glyph 1991 Type: GLYPH_OBJ : ARMOR_CLASS: "white dragon scale mail"
Glyph 1992 Type: GLYPH_OBJ : ARMOR_CLASS: "orange dragon scale mail"
Glyph 1993 Type: GLYPH_OBJ : ARMOR_CLASS: "black dragon scale mail"
Glyph 1994 Type: GLYPH_OBJ : ARMOR_CLASS: "blue dragon scale mail"
Glyph 1995 Type: GLYPH_OBJ : ARMOR_CLASS: "green dragon scale mail"
Glyph 1996 Type: GLYPH_OBJ : ARMOR_CLASS: "yellow dragon scale mail"
Glyph 1997 Type: GLYPH_OBJ : ARMOR_CLASS: "gray dragon scales"
Glyph 1998 Type: GLYPH_OBJ : ARMOR_CLASS: "silver dragon scales"
Glyph 1999 Type: GLYPH_OBJ : ARMOR_CLASS: "red dragon scales"
Glyph 2000 Type: GLYPH_OBJ : ARMOR_CLASS: "white dragon scales"
Glyph 2001 Type: GLYPH_OBJ : ARMOR_CLASS: "orange dragon scales"
Glyph 2002 Type: GLYPH_OBJ : ARMOR_CLASS: "black dragon scales"
Glyph 2003 Type: GLYPH_OBJ : ARMOR_CLASS: "blue dragon scales"
Glyph 2004 Type: GLYPH_OBJ : ARMOR_CLASS: "green dragon scales"
Glyph 2005 Type: GLYPH_OBJ : ARMOR_CLASS: "yellow dragon scales"
Glyph 2006 Type: GLYPH_OBJ : ARMOR_CLASS: "plate mail"
Glyph 2007 Type: GLYPH_OBJ : ARMOR_CLASS: "crystal plate mail"
Glyph 2008 Type: GLYPH_OBJ : ARMOR_CLASS: "bronze plate mail"
Glyph 2009 Type: GLYPH_OBJ : ARMOR_CLASS: "splint mail"
Glyph 2047 Type: GLYPH_OBJ : ARMOR_CLASS: "hard shoes"
Glyph 2048 Type: GLYPH_OBJ : ARMOR_CLASS: "jackboots"
Glyph 2049 Type: GLYPH_OBJ : ARMOR_CLASS: "combat boots"
Glyph 2050 Type: GLYPH_OBJ : ARMOR_CLASS: "jungle boots"
Glyph 2051 Type: GLYPH_OBJ : ARMOR_CLASS: "hiking boots"
Glyph 2052 Type: GLYPH_OBJ : ARMOR_CLASS: "mud boots"
Glyph 2053 Type: GLYPH_OBJ : ARMOR_CLASS: "buckled boots"
Glyph 2054 Type: GLYPH_OBJ : ARMOR_CLASS: "riding boots"
Glyph 2055 Type: GLYPH_OBJ : ARMOR_CLASS: "snow boots"
"""
armor_glossary = armor_glossary.split('\n')[1:-1]
armor_glossary = [x.split('"') for x in armor_glossary]
armor_glossary = [(int(x[0].split()[1]), x[1]) for x in armor_glossary]
armor_glossary = {x:{'name': y} for x, y in armor_glossary}
armor_glossary
# Out:
# {1977: {'name': 'leather hat'},
#  1978: {'name': 'iron skull cap'},
#  1979: {'name': 'hard hat'},
#  1980: {'name': 'fedora'},
#  1981: {'name': 'conical hat'},
#  1982: {'name': 'conical hat'},
#  1983: {'name': 'dented pot'},
#  1984: {'name': 'plumed helmet'},
#  1985: {'name': 'etched helmet'},
#  1986: {'name': 'crested helmet'},
#  1987: {'name': 'visored helmet'},
#  1988: {'name': 'gray dragon scale mail'},
#  1989: {'name': 'silver dragon scale mail'},
#  1990: {'name': 'red dragon scale mail'},
#  1991: {'name': 'white dragon scale mail'},
#  1992: {'name': 'orange dragon scale mail'},
#  1993: {'name': 'black dragon scale mail'},
#  1994: {'name': 'blue dragon scale mail'},
#  1995: {'name': 'green dragon scale mail'},
#  1996: {'name': 'yellow dragon scale mail'},
#  1997: {'name': 'gray dragon scales'},
#  1998: {'name': 'silver dragon scales'},
#  1999: {'name': 'red dragon scales'},
#  2000: {'name': 'white dragon scales'},
#  2001: {'name': 'orange dragon scales'},
#  2002: {'name': 'black dragon scales'},
#  2003: {'name': 'blue dragon scales'},
#  2004: {'name': 'green dragon scales'},
#  2005: {'name': 'yellow dragon scales'},
#  2006: {'name': 'plate mail'},
#  2007: {'name': 'crystal plate mail'},
#  2008: {'name': 'bronze plate mail'},
#  2009: {'name': 'splint mail'},
#  2010: {'name': 'banded mail'},
#  2011: {'name': 'dwarvish mithril-coat'},
#  2012: {'name': 'elven mithril-coat'},
#  2013: {'name': 'chain mail'},
#  2014: {'name': 'crude chain mail'},
#  2015: {'name': 'scale mail'},
#  2016: {'name': 'studded leather armor'},
#  2017: {'name': 'ring mail'},
#  2018: {'name': 'crude ring mail'},
#  2019: {'name': 'leather armor'},
#  2020: {'name': 'leather jacket'},
#  2021: {'name': 'Hawaiian shirt'},
#  2022: {'name': 'T-shirt'},
#  2023: {'name': 'mummy wrapping'},
#  2024: {'name': 'faded pall'},
#  2025: {'name': 'coarse mantelet'},
#  2026: {'name': 'hooded cloak'},
#  2027: {'name': 'slippery cloak'},
#  2028: {'name': 'robe'},
#  2029: {'name': 'apron'},
#  2030: {'name': 'leather cloak'},
#  2031: {'name': 'tattered cape'},
#  2032: {'name': 'opera cloak'},
#  2033: {'name': 'ornamental cope'},
#  2034: {'name': 'piece of cloth'},
#  2035: {'name': 'small shield'},
#  2036: {'name': 'blue and green shield'},
#  2037: {'name': 'white-handed shield'},
#  2038: {'name': 'red-eyed shield'},
#  2039: {'name': 'large shield'},
#  2040: {'name': 'large round shield'},
#  2041: {'name': 'polished silver shield'},
#  2042: {'name': 'old gloves'},
#  2043: {'name': 'padded gloves'},
#  2044: {'name': 'riding gloves'},
#  2045: {'name': 'fencing gloves'},
#  2046: {'name': 'walking shoes'},
#  2047: {'name': 'hard shoes'},
#  2048: {'name': 'jackboots'},
#  2049: {'name': 'combat boots'},
#  2050: {'name': 'jungle boots'},
#  2051: {'name': 'hiking boots'},
#  2052: {'name': 'mud boots'},
#  2053: {'name': 'buckled boots'},
#  2054: {'name': 'riding boots'},
#  2055: {'name': 'snow boots'}}

# %%
mapping = {v['name']: v['name'] for v in armor_glossary.values() if v['name'] in data}

mapping = {
    **mapping, 
    **{x: ' '.join(x.split(' ')[1:]) for x in 
                        ['gray dragon scale mail',
                         'silver dragon scale mail',
                         'red dragon scale mail',
                         'white dragon scale mail',
                         'orange dragon scale mail',
                         'black dragon scale mail',
                         'blue dragon scale mail',
                         'green dragon scale mail',
                         'yellow dragon scale mail',
                         'gray dragon scales',
                         'silver dragon scales',
                         'red dragon scales',
                         'white dragon scales',
                         'orange dragon scales',
                         'black dragon scales',
                         'blue dragon scales',
                         'green dragon scales',
                         'yellow dragon scales',]
    },
    **{x: ' '.join(x.split(' ')[:-1]) for x in 
                       ['blue and green shield',
                        'white-handed shield',
                        'red-eyed shield',
                        'large round shield',
                        'polished silver shield',]
    },
    **{'plate mail': 'plate mail (tanko)'}
}

# %%
armor_glossary = {
    k: {**v, **data[mapping[v['name']]]} for k, v in armor_glossary.items()
}
armor_glossary
# Out:
# {1977: {'name': 'leather hat',
#   'cost': 8,
#   'weight': 3,
#   'AC': 1,
#   'max_AC': 8,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '6',
#   'magical': False,
#   'armor_type': 'helms'},
#  1978: {'name': 'iron skull cap',
#   'cost': 10,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '6',
#   'magical': False,
#   'armor_type': 'helms'},
#  1979: {'name': 'hard hat',
#   'cost': 20,
#   'weight': 40,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '6',
#   'magical': False,
#   'armor_type': 'helms'},
#  1980: {'name': 'fedora',
#   'cost': 1,
#   'weight': 3,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': '',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'helms'},
#  1981: {'name': 'conical hat',
#   'cost': 1,
#   'weight': 4,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Stupid',
#   'MC': '',
#   'probability': '3',
#   'magical': True,
#   'armor_type': 'helms'},
#  1982: {'name': 'conical hat',
#   'cost': 1,
#   'weight': 4,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Stupid',
#   'MC': '',
#   'probability': '3',
#   'magical': True,
#   'armor_type': 'helms'},
#  1983: {'name': 'dented pot',
#   'cost': 8,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'helms'},
#  1984: {'name': 'plumed helmet',
#   'cost': 10,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '10',
#   'magical': False,
#   'armor_type': 'helms'},
#  1985: {'name': 'etched helmet',
#   'cost': 50,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'Int+Wis',
#   'MC': '',
#   'probability': '6',
#   'magical': True,
#   'armor_type': 'helms'},
#  1986: {'name': 'crested helmet',
#   'cost': 50,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'Align',
#   'MC': '',
#   'probability': '6',
#   'magical': True,
#   'armor_type': 'helms'},
#  1987: {'name': 'visored helmet',
#   'cost': 50,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'ESP',
#   'MC': '',
#   'probability': '2',
#   'magical': True,
#   'armor_type': 'helms'},
#  1988: {'name': 'gray dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1989: {'name': 'silver dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1990: {'name': 'red dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1991: {'name': 'white dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1992: {'name': 'orange dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1993: {'name': 'black dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1994: {'name': 'blue dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1995: {'name': 'green dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1996: {'name': 'yellow dragon scale mail',
#   'cost': 900,
#   'weight': 40,
#   'AC': 9,
#   'max_AC': 14,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': True,
#   'armor_type': 'dragon suits'},
#  1997: {'name': 'gray dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  1998: {'name': 'silver dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  1999: {'name': 'red dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  2000: {'name': 'white dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  2001: {'name': 'orange dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  2002: {'name': 'black dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  2003: {'name': 'blue dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  2004: {'name': 'green dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  2005: {'name': 'yellow dragon scales',
#   'cost': 500,
#   'weight': 40,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'dragon',
#   'effect': 'Resist%',
#   'MC': '',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'dragon suits'},
#  2006: {'name': 'plate mail',
#   'cost': 600,
#   'weight': 450,
#   'AC': 7,
#   'max_AC': 12,
#   'material': 'iron',
#   'effect': '',
#   'MC': '2',
#   'probability': '44',
#   'magical': False,
#   'armor_type': 'suits'},
#  2007: {'name': 'crystal plate mail',
#   'cost': 820,
#   'weight': 450,
#   'AC': 7,
#   'max_AC': 12,
#   'material': 'glass',
#   'effect': '',
#   'MC': '2',
#   'probability': '10',
#   'magical': False,
#   'armor_type': 'suits'},
#  2008: {'name': 'bronze plate mail',
#   'cost': 400,
#   'weight': 450,
#   'AC': 6,
#   'max_AC': 11,
#   'material': 'copper',
#   'effect': '',
#   'MC': '1',
#   'probability': '25',
#   'magical': False,
#   'armor_type': 'suits'},
#  2009: {'name': 'splint mail',
#   'cost': 80,
#   'weight': 400,
#   'AC': 6,
#   'max_AC': 11,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '62',
#   'magical': False,
#   'armor_type': 'suits'},
#  2010: {'name': 'banded mail',
#   'cost': 90,
#   'weight': 350,
#   'AC': 6,
#   'max_AC': 11,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  2011: {'name': 'dwarvish mithril-coat',
#   'cost': 240,
#   'weight': 150,
#   'AC': 6,
#   'max_AC': 11,
#   'material': 'mithril',
#   'effect': '',
#   'MC': '2',
#   'probability': '10',
#   'magical': False,
#   'armor_type': 'suits'},
#  2012: {'name': 'elven mithril-coat',
#   'cost': 240,
#   'weight': 150,
#   'AC': 5,
#   'max_AC': 12,
#   'material': 'mithril',
#   'effect': '',
#   'MC': '2',
#   'probability': '15',
#   'magical': False,
#   'armor_type': 'suits'},
#  2013: {'name': 'chain mail',
#   'cost': 75,
#   'weight': 300,
#   'AC': 5,
#   'max_AC': 10,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  2014: {'name': 'crude chain mail',
#   'cost': 75,
#   'weight': 300,
#   'AC': 4,
#   'max_AC': 9,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '20',
#   'magical': False,
#   'armor_type': 'suits'},
#  2015: {'name': 'scale mail',
#   'cost': 45,
#   'weight': 250,
#   'AC': 4,
#   'max_AC': 9,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  2016: {'name': 'studded leather armor',
#   'cost': 15,
#   'weight': 200,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'leather',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  2017: {'name': 'ring mail',
#   'cost': 100,
#   'weight': 250,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '72',
#   'magical': False,
#   'armor_type': 'suits'},
#  2018: {'name': 'crude ring mail',
#   'cost': 80,
#   'weight': 250,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '1',
#   'probability': '20',
#   'magical': False,
#   'armor_type': 'suits'},
#  2019: {'name': 'leather armor',
#   'cost': 5,
#   'weight': 150,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'leather',
#   'effect': '',
#   'MC': '1',
#   'probability': '82',
#   'magical': False,
#   'armor_type': 'suits'},
#  2020: {'name': 'leather jacket',
#   'cost': 10,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '12',
#   'magical': False,
#   'armor_type': 'suits'},
#  2021: {'name': 'Hawaiian shirt',
#   'cost': 3,
#   'weight': 5,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Shop',
#   'MC': '',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'shirts'},
#  2022: {'name': 'T-shirt',
#   'cost': 2,
#   'weight': 5,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Shop',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'shirts'},
#  2023: {'name': 'mummy wrapping',
#   'cost': 2,
#   'weight': 3,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': 'Vis',
#   'MC': '1',
#   'probability': '--',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  2024: {'name': 'faded pall',
#   'cost': 60,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 8,
#   'material': 'cloth',
#   'effect': 'Stealth',
#   'MC': '1',
#   'probability': '8',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  2025: {'name': 'coarse mantelet',
#   'cost': 40,
#   'weight': 10,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': '',
#   'MC': '1',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  2026: {'name': 'hooded cloak',
#   'cost': 50,
#   'weight': 10,
#   'AC': 0,
#   'max_AC': 5,
#   'material': 'cloth',
#   'effect': '',
#   'MC': '1',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  2027: {'name': 'slippery cloak',
#   'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Water',
#   'MC': '2',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  2028: {'name': 'robe',
#   'cost': 50,
#   'weight': 15,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'cloth',
#   'effect': 'Spell1',
#   'MC': '2',
#   'probability': '3',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  2029: {'name': 'apron',
#   'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Poi+Acd',
#   'MC': '1',
#   'probability': '9',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  2030: {'name': 'leather cloak',
#   'cost': 40,
#   'weight': 15,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': '',
#   'MC': '1',
#   'probability': '8',
#   'magical': False,
#   'armor_type': 'cloaks'},
#  2031: {'name': 'tattered cape',
#   'cost': 50,
#   'weight': 10,
#   'AC': 3,
#   'max_AC': 8,
#   'material': 'cloth',
#   'effect': 'Prot',
#   'MC': '3',
#   'probability': '9',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  2032: {'name': 'opera cloak',
#   'cost': 60,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Invis',
#   'MC': '1',
#   'probability': '10',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  2033: {'name': 'ornamental cope',
#   'cost': 60,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Magic',
#   'MC': '1',
#   'probability': '2',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  2034: {'name': 'piece of cloth',
#   'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'cloth',
#   'effect': 'Displ',
#   'MC': '1',
#   'probability': '10',
#   'magical': True,
#   'armor_type': 'cloaks'},
#  2035: {'name': 'small shield',
#   'cost': 3,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'wood',
#   'effect': 'Spell2',
#   'MC': '',
#   'probability': '6',
#   'magical': False,
#   'armor_type': 'shields'},
#  2036: {'name': 'blue and green shield',
#   'cost': 7,
#   'weight': 40,
#   'AC': 2,
#   'max_AC': 9,
#   'material': 'wood',
#   'effect': '',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'shields'},
#  2037: {'name': 'white-handed shield',
#   'cost': 7,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'shields'},
#  2038: {'name': 'red-eyed shield',
#   'cost': 7,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '2',
#   'magical': False,
#   'armor_type': 'shields'},
#  2039: {'name': 'large shield',
#   'cost': 10,
#   'weight': 100,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '7',
#   'magical': False,
#   'armor_type': 'shields'},
#  2040: {'name': 'large round shield',
#   'cost': 10,
#   'weight': 100,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '4',
#   'magical': False,
#   'armor_type': 'shields'},
#  2041: {'name': 'polished silver shield',
#   'cost': 50,
#   'weight': 50,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'silver',
#   'effect': 'Reflect',
#   'MC': '',
#   'probability': '3',
#   'magical': True,
#   'armor_type': 'shields'},
#  2042: {'name': 'old gloves',
#   'cost': 8,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '16',
#   'magical': False,
#   'armor_type': 'gloves'},
#  2043: {'name': 'padded gloves',
#   'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Dex',
#   'MC': '',
#   'probability': '8',
#   'magical': True,
#   'armor_type': 'gloves'},
#  2044: {'name': 'riding gloves',
#   'cost': 50,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Fumble',
#   'MC': '',
#   'probability': '8',
#   'magical': True,
#   'armor_type': 'gloves'},
#  2045: {'name': 'fencing gloves',
#   'cost': 50,
#   'weight': 30,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'Str',
#   'MC': '',
#   'probability': '8',
#   'magical': True,
#   'armor_type': 'gloves'},
#  2046: {'name': 'walking shoes',
#   'cost': 8,
#   'weight': 10,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '25',
#   'magical': False,
#   'armor_type': 'boots'},
#  2047: {'name': 'hard shoes',
#   'cost': 16,
#   'weight': 50,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'iron',
#   'effect': '',
#   'MC': '',
#   'probability': '7',
#   'magical': False,
#   'armor_type': 'boots'},
#  2048: {'name': 'jackboots',
#   'cost': 12,
#   'weight': 20,
#   'AC': 2,
#   'max_AC': 7,
#   'material': 'leather',
#   'effect': '',
#   'MC': '',
#   'probability': '15',
#   'magical': False,
#   'armor_type': 'boots'},
#  2049: {'name': 'combat boots',
#   'cost': 50,
#   'weight': 20,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Speed',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  2050: {'name': 'jungle boots',
#   'cost': 50,
#   'weight': 20,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'WWalk',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  2051: {'name': 'hiking boots',
#   'cost': 50,
#   'weight': 20,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Jump',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  2052: {'name': 'mud boots',
#   'cost': 8,
#   'weight': 15,
#   'AC': 1,
#   'max_AC': 8,
#   'material': 'leather',
#   'effect': 'Stealth',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  2053: {'name': 'buckled boots',
#   'cost': 8,
#   'weight': 50,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'iron',
#   'effect': 'Kick',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  2054: {'name': 'riding boots',
#   'cost': 30,
#   'weight': 20,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Fumble',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'},
#  2055: {'name': 'snow boots',
#   'cost': 30,
#   'weight': 15,
#   'AC': 1,
#   'max_AC': 6,
#   'material': 'leather',
#   'effect': 'Lev',
#   'MC': '',
#   'probability': '12',
#   'magical': True,
#   'armor_type': 'boots'}}

# %% [markdown]
# ## WEAPON

# %%
URL = 'https://nethackwiki.com/wiki/Weapon'
response = requests.get(URL)
soup = BeautifulSoup(response.text,'html.parser')

tables = soup.find_all('table',{'class':'prettytable'})
tables[1]
# Out:
# <table class="prettytable striped sortable">
# <tbody><tr>
# <th>Weapon</th>
# <th>Skill</th>
# <th data-sort-type="number">Cost</th>
# <th>Weight</th>
# <th data-sort-type="number">Prob (‰)</th>
# <th class="unsortable" colspan="2"><span class="explain" title="Damage to small/large monster">Damage (S/L)</span></th>
# <th>Material</th>
# <th>Appearance</th>
# <th class="unsortable">Tile</th>
# <th class="unsortable">Glyph
# </th></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Orcish_dagger" title="Orcish dagger">orcish dagger</a></td>
# <td>dagger</td>
# <td>4 zm</td>
# <td>10</td>
# <td>12<sup>†</sup></td>
# <td>d3</td>
# <td>d3</td>
# <td>iron</td>
# <td>crude dagger</td>
# <td><a class="image" href="/wiki/File:Orcish_dagger.png"><img alt="Orcish dagger.png" height="16" src="/mediawiki/images/8/8b/Orcish_dagger.png" width="16"/></a></td>
# <td><span class="nhsym clr-darkgray">)</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Dagger" title="Dagger">dagger</a></td>
# <td>dagger</td>
# <td>4 zm</td>
# <td>10</td>
# <td>30</td>
# <td>d4</td>
# <td>d3</td>
# <td>iron</td>
# <td></td>
# <td><a class="image" href="/wiki/File:Dagger.png"><img alt="Dagger.png" height="16" src="/mediawiki/images/4/45/Dagger.png" width="16"/></a></td>
# <td><span class="nhsym clr-cyan">)</span>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Silver_dagger" title="Silver dagger">silver dagger</a></td>
# <td>dagger</td>
# <td>40 zm</td>
# <td>12</td>
# <td>3</td>
# <td>d4</td>
# <td>d3</td>
# <td>silver</td>
# <td></td>
# <td><a class="image" href="/wiki/File:Silver_dagger.png"><img alt="Silver dagger.png" height="16" src="/mediawiki/images/0/05/Silver_dagger.png" width="16"/></a></td>
# <td><span class="nhsym clr-lightgray">)</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Athame" title="Athame">athame</a></td>
# <td>dagger</td>
# <td>4 zm</td>
# <td>10</td>
# <td>N/A</td>
# <td>d4</td>
# <td>d3</td>
# <td>iron</td>
# <td></td>
# <td><a class="image" href="/wiki/File:Athame.png"><img alt="Athame.png" height="16" src="/mediawiki/images/0/02/Athame.png" width="16"/></a></td>
# <td><span class="nhsym clr-cyan">)</span>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/
png" width="16"/></a></td>
# <td><span class="nhsym clr-cyan">)</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Shuriken" title="Shuriken">shuriken</a></td>
# <td>shuriken</td>
# <td>5 zm</td>
# <td>1</td>
# <td>35</td>
# <td>d8</td>
# <td>d6</td>
# <td>iron</td>
# <td>throwing star</td>
# <td><a class="image" href="/wiki/File:Shuriken.png"><img alt="Shuriken.png" height="16" src="/mediawiki/images/a/ac/Shuriken.png" width="16"/></a></td>
# <td><span class="nhsym clr-cyan">)</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Boomerang" title="Boomerang">boomerang</a></td>
# <td>boomerang</td>
# <td>20 zm</td>
# <td>5</td>
# <td>15</td>
# <td>d9</td>
# <td>d9</td>
# <td>wood</td>
# <td></td>
# <td><a class="image" href="/wiki/File:Boomerang.png"><img alt="Boomerang.png" height="16" src="/mediawiki/images/7/7c/Boomerang.png" width="16"/></a></td>
# <td><span class="nhsym clr-brown">)</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Bullwhip" title="Bullwhip">bullwhip</a></td>
# <td>whip</td>
# <td>4 zm</td>
# <td>20</td>
# <td>2</td>
# <td>d2</td>
# <td>1</td>
# <td>leather</td>
# <td></td>
# <td><a class="image" href="/wiki/File:Bullwhip.png"><img alt="Bullwhip.png" height="16" src="/mediawiki/images/4/44/Bullwhip.png" width="16"/></a></td>
# <td><span class="nhsym clr-brown">)</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Rubber_hose" title="Rubber hose">rubber hose</a></td>
# <td>whip</td>
# <td>3 zm</td>
# <td>20</td>
# <td>N/A</td>
# <td>d4</td>
# <td>d3</td>
# <td>plastic</td>
# <td></td>
# <td><a class="image" href="/wiki/File:Rubber_hose.png"><img alt="Rubber hose.png" height="16" src="/mediawiki/images/2/26/Rubber_hose.png" width="16"/></a></td>
# <td><span class="nhsym clr-brown">)</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Unicorn_horn" title="Unicorn horn">unicorn horn</a></td>
# <td>unicorn horn</td>
# <td>100 zm</td>
# <td>20</td>
# <td>tool</td>
# <td>d12</td>
# <td>d12</td>
# <td>bone</td>
# <td></td>
# <td><a class="image" href="/wiki/File:Unicorn_horn.png"><img alt="Unicorn horn.png" height="16" src="/mediawiki/images/6/65/Unicorn_horn.png" width="16"/></a></td>
# <td><span class="nhsym clr-white">(</span>
# </td></tr></tbody></table>

# %%
table = tables[1]

rows = table.find_all('tr')
# columns = [v.text.replace('\n','') for v in rows[0].find_all('th')]
columns = ['name',
 'skill',
 'cost',
 'weight',
 'probability',
 'damage_S',
 'damage_L',
 'material',
 'appearance'
]
df = pd.DataFrame(columns=columns)

for i in range(1,len(rows)):
    tds = rows[i].find_all('td')
    values = [td.text.replace('\n','') for td in tds][:-2]
    df = df.append(pd.Series(values, index=columns), ignore_index=True)

df = df[df['name'] != 'runesword'] 
    
df.loc[df['appearance'] != '', 'name'] = df['appearance']
df['weight'] = df['weight'].astype(int)
df['cost'] = df['cost'].apply(lambda x: int(x.split()[0]))
df.drop(columns = ['appearance'], inplace=True)
df
# Out:
#              name         skill  cost  weight probability damage_S damage_L  \
# 0    crude dagger        dagger     4      10         12†       d3       d3
# 1          dagger        dagger     4      10          30       d4       d3
# 2   silver dagger        dagger    40      12           3       d4       d3
# 3          athame        dagger     4      10         N/A       d4       d3
# 4    runed dagger        dagger     4      10         10†       d5       d3
# ..            ...           ...   ...     ...         ...      ...      ...
# 69  throwing star      shuriken     5       1          35       d8       d6
# 70      boomerang     boomerang    20       5          15       d9       d9
# 71       bullwhip          whip     4      20           2       d2        1
# 72    rubber hose          whip     3      20         N/A       d4       d3
# 73   unicorn horn  unicorn horn   100      20        tool      d12      d12
#
#    material
# 0      iron
# 1      iron
# 2    silver
# 3      iron
# 4      wood
# ..      ...
# 69     iron
# 70     wood
# 71  leather
# 72  plastic
# 73     bone
#
# [73 rows x 8 columns]

# %%
data = df.set_index('name').to_dict('index')
data
# Out:
# {'crude dagger': {'skill': 'dagger',
#   'cost': 4,
#   'weight': 10,
#   'probability': '12†',
#   'damage_S': 'd3',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  'dagger': {'skill': 'dagger',
#   'cost': 4,
#   'weight': 10,
#   'probability': '30',
#   'damage_S': 'd4',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  'silver dagger': {'skill': 'dagger',
#   'cost': 40,
#   'weight': 12,
#   'probability': '3',
#   'damage_S': 'd4',
#   'damage_L': 'd3',
#   'material': 'silver'},
#  'athame': {'skill': 'dagger',
#   'cost': 4,
#   'weight': 10,
#   'probability': 'N/A',
#   'damage_S': 'd4',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  'runed dagger': {'skill': 'dagger',
#   'cost': 4,
#   'weight': 10,
#   'probability': '10†',
#   'damage_S': 'd5',
#   'damage_L': 'd3',
#   'material': 'wood'},
#  'worm tooth': {'skill': 'knife',
#   'cost': 2,
#   'weight': 20,
#   'probability': 'N/A',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'undefined'},
#  'knife (shito)': {'skill': 'knife',
#   'cost': 4,
#   'weight': 5,
#   'probability': '20',
#   'damage_S': 'd3',
#   'damage_L': 'd2',
#   'material': 'iron'},
#  'stiletto': {'skill': 'knife',
#   'cost': 4,
#   'weight': 5,
#   'probability': '5',
#   'damage_S': 'd3',
#   'damage_L': 'd2',
#   'material': 'iron'},
#  'scalpel': {'skill': 'knife',
#   'cost': 4,
#   'weight': 5,
#   'probability': 'N/A',
#   'damage_S': 'd3',
#   'damage_L': 'd3',
#   'material': 'metal'},
#  'crysknife': {'skill': 'knife',
#   'cost': 100,
#   'weight': 20,
#   'probability': 'N/A',
#   'damage_S': 'd10',
#   'damage_L': 'd10',
#   'material': 'mineral'},
#  'axe': {'skill': 'axe',
#   'cost': 8,
#   'weight': 60,
#   'probability': '40',
#   'damage_S': 'd6',
#   'damage_L': 'd4',
#   'material': 'iron'},
#  'double-headed axe': {'skill': 'axe',
#   'cost': 40,
#   'weight': 120,
#   'probability': '10',
#   'damage_S': 'd8+d4',
#   'damage_L': 'd6+2d4',
#   'material': 'iron'},
#  'pick-axe': {'skill': 'pick-axe',
#   'cost': 50,
#   'weight': 100,
#   'probability': 'tool',
#   'damage_S': 'd6',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  'broad pick': {'skill': 'pick-axe',
#   'cost': 50,
#   'weight': 120,
#   'probability': '13†',
#   'damage_S': 'd12',
#   'damage_L': 'd8+2d6',
#   'material': 'iron'},
#  'crude short sword': {'skill': 'short sword',
#   'cost': 10,
#   'weight': 30,
#   'probability': '3†',
#   'damage_S': 'd5',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'short sword (wakizashi)': {'skill': 'short sword',
#   'cost': 10,
#   'weight': 30,
#   'probability': '8',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'broad short sword': {'skill': 'short sword',
#   'cost': 10,
#   'weight': 30,
#   'probability': '2†',
#   'damage_S': 'd7',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'runed short sword': {'skill': 'short sword',
#   'cost': 10,
#   'weight': 30,
#   'probability': '2†',
#   'damage_S': 'd8',
#   'damage_L': 'd8',
#   'material': 'wood'},
#  'broadsword (ninja-to)': {'skill': 'broadsword',
#   'cost': 10,
#   'weight': 70,
#   'probability': '8',
#   'damage_S': '2d4',
#   'damage_L': 'd6+1',
#   'material': 'iron'},
#  'runed broadsword': {'skill': 'broadsword',
#   'cost': 10,
#   'weight': 70,
#   'probability': '4†',
#   'damage_S': 'd6+d4',
#   'damage_L': 'd6+1',
#   'material': 'wood'},
#  'long sword': {'skill': 'long sword',
#   'cost': 15,
#   'weight': 40,
#   'probability': '50†',
#   'damage_S': 'd8',
#   'damage_L': 'd12',
#   'material': 'iron'},
#  'samurai sword': {'skill': 'long sword',
#   'cost': 80,
#   'weight': 40,
#   'probability': '4',
#   'damage_S': 'd10',
#   'damage_L': 'd12',
#   'material': 'iron'},
#  'two-handed sword': {'skill': 'two-handed sword',
#   'cost': 50,
#   'weight': 150,
#   'probability': '22',
#   'damage_S': 'd12',
#   'damage_L': '3d6',
#   'material': 'iron'},
#  'long samurai sword': {'skill': 'two-handed sword',
#   'cost': 500,
#   'weight': 60,
#   'probability': 'N/A',
#   'damage_S': 'd16',
#   'damage_L': 'd8+2d6',
#   'material': 'metal'},
#  'curved sword': {'skill': 'scimitar',
#   'cost': 15,
#   'weight': 40,
#   'probability': '15†',
#   'damage_S': 'd8',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'silver saber': {'skill': 'saber',
#   'cost': 75,
#   'weight': 40,
#   'probability': '6',
#   'damage_S': 'd8',
#   'damage_L': 'd8',
#   'material': 'silver'},
#  'club': {'skill': 'club',
#   'cost': 3,
#   'weight': 30,
#   'probability': '12',
#   'damage_S': 'd6',
#   'damage_L': 'd3',
#   'material': 'wood'},
#  'thonged club': {'skill': 'club',
#   'cost': 4,
#   'weight': 15,
#   'probability': '8',
#   'damage_S': 'd6',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  'mace': {'skill': 'mace',
#   'cost': 5,
#   'weight': 30,
#   'probability': '40',
#   'damage_S': 'd6+1',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  'morning star': {'skill': 'morning star',
#   'cost': 10,
#   'weight': 120,
#   'probability': '12',
#   'damage_S': '2d4',
#   'damage_L': 'd6+1',
#   'material': 'iron'},
#  'flail (nunchaku)': {'skill': 'flail',
#   'cost': 4,
#   'weight': 15,
#   'probability': '40',
#   'damage_S': 'd6+1',
#   'damage_L': '2d4',
#   'material': 'iron'},
#  'iron hook': {'skill': 'flail',
#   'cost': 50,
#   'weight': 30,
#   'probability': 'tool',
#   'damage_S': 'd2',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  'war hammer': {'skill': 'hammer',
#   'cost': 5,
#   'weight': 50,
#   'probability': '15',
#   'damage_S': 'd4+1',
#   'damage_L': 'd4',
#   'material': 'iron'},
#  'staff': {'skill': 'quarterstaff',
#   'cost': 5,
#   'weight': 40,
#   'probability': '11†',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'wood'},
#  'vulgar polearm': {'skill': 'polearms',
#   'cost': 10,
#   'weight': 80,
#   'probability': '5',
#   'damage_S': 'd6',
#   'damage_L': 'd6+1',
#   'material': 'iron'},
#  'pole sickle': {'skill': 'polearms',
#   'cost': 5,
#   'weight': 60,
#   'probability': '6',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'single-edged polearm': {'skill': 'polearms',
#   'cost': 6,
#   'weight': 75,
#   'probability': '8',
#   'damage_S': 'd6',
#   'damage_L': 'd10',
#   'material': 'iron'},
#  'beaked polearm': {'skill': 'polearms',
#   'cost': 8,
#   'weight': 100,
#   'probability': '4',
#   'damage_S': 'd8',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  'forked polearm': {'skill': 'polearms',
#   'cost': 5,
#   'weight': 50,
#   'probability': '5',
#   'damage_S': 'd6+1',
#   'damage_L': '2d6',
#   'material': 'iron'},
#  'pronged polearm': {'skill': 'polearms',
#   'cost': 7,
#   'weight': 150,
#   'probability': '5',
#   'damage_S': '2d4',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  'pruning hook': {'skill': 'polearms',
#   'cost': 5,
#   'weight': 80,
#   'probability': '6',
#   'damage_S': '2d4',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'hilted polearm': {'skill': 'polearms',
#   'cost': 6,
#   'weight': 50,
#   'probability': '5',
#   'damage_S': '2d4',
#   'damage_L': '2d4',
#   'material': 'iron'},
#  'pole cleaver': {'skill': 'polearms',
#   'cost': 5,
#   'weight': 125,
#   'probability': '4',
#   'damage_S': '2d4',
#   'damage_L': '2d4',
#   'material': 'iron'},
#  'hooked polearm': {'skill': 'polearms',
#   'cost': 7,
#   'weight': 120,
#   'probability': '4',
#   'damage_S': '2d4',
#   'damage_L': 'd10',
#   'material': 'iron'},
#  'long poleaxe': {'skill': 'polearms',
#   'cost': 7,
#   'weight': 120,
#   'probability': '4',
#   'damage_S': '2d4',
#   'damage_L': '3d4',
#   'material': 'iron'},
#  'angled poleaxe': {'skill': 'polearms',
#   'cost': 10,
#   'weight': 150,
#   'probability': '8',
#   'damage_S': 'd10',
#   'damage_L': '2d6',
#   'material': 'iron'},
#  'crude spear': {'skill': 'spear',
#   'cost': 3,
#   'weight': 30,
#   'probability': '13†',
#   'damage_S': 'd5',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'spear': {'skill': 'spear',
#   'cost': 3,
#   'weight': 30,
#   'probability': '50†',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'silver spear': {'skill': 'spear',
#   'cost': 40,
#   'weight': 36,
#   'probability': '2',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'silver'},
#  'runed spear': {'skill': 'spear',
#   'cost': 3,
#   'weight': 30,
#   'probability': '10†',
#   'damage_S': 'd7',
#   'damage_L': 'd8',
#   'material': 'wood'},
#  'stout spear': {'skill': 'spear',
#   'cost': 3,
#   'weight': 35,
#   'probability': '12†',
#   'damage_S': 'd8',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'throwing spear': {'skill': 'spear',
#   'cost': 3,
#   'weight': 20,
#   'probability': '10',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  'trident': {'skill': 'trident',
#   'cost': 5,
#   'weight': 25,
#   'probability': '8',
#   'damage_S': 'd6+1',
#   'damage_L': '3d4',
#   'material': 'iron'},
#  'lance (1)': {'skill': 'lance',
#   'cost': 10,
#   'weight': 180,
#   'probability': '4',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  'crude bow': {'skill': 'bow',
#   'cost': 60,
#   'weight': 30,
#   'probability': '12†',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  'crude arrow': {'skill': 'bow',
#   'cost': 2,
#   'weight': 1,
#   'probability': '20†',
#   'damage_S': 'd5',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  'bow': {'skill': 'bow',
#   'cost': 60,
#   'weight': 30,
#   'probability': '24',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  'arrow': {'skill': 'bow',
#   'cost': 2,
#   'weight': 1,
#   'probability': '55†',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  'runed bow': {'skill': 'bow',
#   'cost': 60,
#   'weight': 30,
#   'probability': '12†',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  'runed arrow': {'skill': 'bow',
#   'cost': 2,
#   'weight': 1,
#   'probability': '20†',
#   'damage_S': 'd7',
#   'damage_L': 'd6',
#   'material': 'wood'},
#  'long bow': {'skill': 'bow',
#   'cost': 60,
#   'weight': 30,
#   'probability': '0',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  'bamboo arrow': {'skill': 'bow',
#   'cost': 4,
#   'weight': 1,
#   'probability': '15',
#   'damage_S': 'd7',
#   'damage_L': 'd7',
#   'material': 'metal'},
#  'silver arrow': {'skill': 'bow',
#   'cost': 5,
#   'weight': 1,
#   'probability': '12',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'silver'},
#  'sling': {'skill': 'sling',
#   'cost': 20,
#   'weight': 3,
#   'probability': '40',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'leather'},
#  'gray stone': {'skill': 'sling',
#   'cost': 1,
#   'weight': 10,
#   'probability': 'gem',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'mineral'},
#  'crossbow': {'skill': 'crossbow',
#   'cost': 40,
#   'weight': 50,
#   'probability': '45†',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  'crossbow bolt': {'skill': 'crossbow',
#   'cost': 2,
#   'weight': 1,
#   'probability': '55†',
#   'damage_S': 'd4+1',
#   'damage_L': 'd6+1',
#   'material': 'iron'},
#  'dart': {'skill': 'dart',
#   'cost': 2,
#   'weight': 1,
#   'probability': '60†',
#   'damage_S': 'd3',
#   'damage_L': 'd2',
#   'material': 'iron'},
#  'throwing star': {'skill': 'shuriken',
#   'cost': 5,
#   'weight': 1,
#   'probability': '35',
#   'damage_S': 'd8',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  'boomerang': {'skill': 'boomerang',
#   'cost': 20,
#   'weight': 5,
#   'probability': '15',
#   'damage_S': 'd9',
#   'damage_L': 'd9',
#   'material': 'wood'},
#  'bullwhip': {'skill': 'whip',
#   'cost': 4,
#   'weight': 20,
#   'probability': '2',
#   'damage_S': 'd2',
#   'damage_L': '1',
#   'material': 'leather'},
#  'rubber hose': {'skill': 'whip',
#   'cost': 3,
#   'weight': 20,
#   'probability': 'N/A',
#   'damage_S': 'd4',
#   'damage_L': 'd3',
#   'material': 'plastic'},
#  'unicorn horn': {'skill': 'unicorn horn',
#   'cost': 100,
#   'weight': 20,
#   'probability': 'tool',
#   'damage_S': 'd12',
#   'damage_L': 'd12',
#   'material': 'bone'}}

# %%
weapon_glossary = """
Glyph 1907 Type: GLYPH_OBJ : WEAPON_CLASS: "arrow"
Glyph 1908 Type: GLYPH_OBJ : WEAPON_CLASS: "runed arrow"
Glyph 1909 Type: GLYPH_OBJ : WEAPON_CLASS: "crude arrow"
Glyph 1910 Type: GLYPH_OBJ : WEAPON_CLASS: "silver arrow"
Glyph 1911 Type: GLYPH_OBJ : WEAPON_CLASS: "bamboo arrow"
Glyph 1912 Type: GLYPH_OBJ : WEAPON_CLASS: "crossbow bolt"
Glyph 1913 Type: GLYPH_OBJ : WEAPON_CLASS: "dart"
Glyph 1914 Type: GLYPH_OBJ : WEAPON_CLASS: "throwing star"
Glyph 1915 Type: GLYPH_OBJ : WEAPON_CLASS: "boomerang"
Glyph 1916 Type: GLYPH_OBJ : WEAPON_CLASS: "spear"
Glyph 1917 Type: GLYPH_OBJ : WEAPON_CLASS: "runed spear"
Glyph 1918 Type: GLYPH_OBJ : WEAPON_CLASS: "crude spear"
Glyph 1957 Type: GLYPH_OBJ : WEAPON_CLASS: "pole sickle"
Glyph 1958 Type: GLYPH_OBJ : WEAPON_CLASS: "pruning hook"
Glyph 1959 Type: GLYPH_OBJ : WEAPON_CLASS: "hooked polearm"
Glyph 1960 Type: GLYPH_OBJ : WEAPON_CLASS: "pronged polearm"
Glyph 1961 Type: GLYPH_OBJ : WEAPON_CLASS: "beaked polearm"
Glyph 1962 Type: GLYPH_OBJ : WEAPON_CLASS: "mace"
Glyph 1963 Type: GLYPH_OBJ : WEAPON_CLASS: "morning star"
Glyph 1964 Type: GLYPH_OBJ : WEAPON_CLASS: "war hammer"
Glyph 1965 Type: GLYPH_OBJ : WEAPON_CLASS: "club"
Glyph 1966 Type: GLYPH_OBJ : WEAPON_CLASS: "rubber hose"
Glyph 1967 Type: GLYPH_OBJ : WEAPON_CLASS: "staff"
Glyph 1968 Type: GLYPH_OBJ : WEAPON_CLASS: "thonged club"
Glyph 1969 Type: GLYPH_OBJ : WEAPON_CLASS: "flail"
Glyph 1970 Type: GLYPH_OBJ : WEAPON_CLASS: "bullwhip"
Glyph 1971 Type: GLYPH_OBJ : WEAPON_CLASS: "bow"
Glyph 1972 Type: GLYPH_OBJ : WEAPON_CLASS: "runed bow"
Glyph 1973 Type: GLYPH_OBJ : WEAPON_CLASS: "crude bow"
Glyph 1974 Type: GLYPH_OBJ : WEAPON_CLASS: "long bow"
Glyph 1975 Type: GLYPH_OBJ : WEAPON_CLASS: "sling"
Glyph 1976 Type: GLYPH_OBJ : WEAPON_CLASS: "crossbow"
"""
weapon_glossary = weapon_glossary.split('\n')[1:-1]
weapon_glossary = [x.split('"') for x in weapon_glossary]
weapon_glossary = [(int(x[0].split()[1]), x[1]) for x in weapon_glossary]
weapon_glossary = {x:{'name': y} for x, y in weapon_glossary}
weapon_glossary
# Out:
# {1907: {'name': 'arrow'},
#  1908: {'name': 'runed arrow'},
#  1909: {'name': 'crude arrow'},
#  1910: {'name': 'silver arrow'},
#  1911: {'name': 'bamboo arrow'},
#  1912: {'name': 'crossbow bolt'},
#  1913: {'name': 'dart'},
#  1914: {'name': 'throwing star'},
#  1915: {'name': 'boomerang'},
#  1916: {'name': 'spear'},
#  1917: {'name': 'runed spear'},
#  1918: {'name': 'crude spear'},
#  1919: {'name': 'stout spear'},
#  1920: {'name': 'silver spear'},
#  1921: {'name': 'throwing spear'},
#  1922: {'name': 'trident'},
#  1923: {'name': 'dagger'},
#  1924: {'name': 'runed dagger'},
#  1925: {'name': 'crude dagger'},
#  1926: {'name': 'silver dagger'},
#  1927: {'name': 'athame'},
#  1928: {'name': 'scalpel'},
#  1929: {'name': 'knife'},
#  1930: {'name': 'stiletto'},
#  1931: {'name': 'worm tooth'},
#  1932: {'name': 'crysknife'},
#  1933: {'name': 'axe'},
#  1934: {'name': 'double-headed axe'},
#  1935: {'name': 'short sword'},
#  1936: {'name': 'runed short sword'},
#  1937: {'name': 'crude short sword'},
#  1938: {'name': 'broad short sword'},
#  1939: {'name': 'curved sword'},
#  1940: {'name': 'silver saber'},
#  1941: {'name': 'broadsword'},
#  1942: {'name': 'runed broadsword'},
#  1943: {'name': 'long sword'},
#  1944: {'name': 'two-handed sword'},
#  1945: {'name': 'samurai sword'},
#  1946: {'name': 'long samurai sword'},
#  1947: {'name': 'runed broadsword'},
#  1948: {'name': 'vulgar polearm'},
#  1949: {'name': 'hilted polearm'},
#  1950: {'name': 'forked polearm'},
#  1951: {'name': 'single-edged polearm'},
#  1952: {'name': 'lance'},
#  1953: {'name': 'angled poleaxe'},
#  1954: {'name': 'long poleaxe'},
#  1955: {'name': 'pole cleaver'},
#  1956: {'name': 'broad pick'},
#  1957: {'name': 'pole sickle'},
#  1958: {'name': 'pruning hook'},
#  1959: {'name': 'hooked polearm'},
#  1960: {'name': 'pronged polearm'},
#  1961: {'name': 'beaked polearm'},
#  1962: {'name': 'mace'},
#  1963: {'name': 'morning star'},
#  1964: {'name': 'war hammer'},
#  1965: {'name': 'club'},
#  1966: {'name': 'rubber hose'},
#  1967: {'name': 'staff'},
#  1968: {'name': 'thonged club'},
#  1969: {'name': 'flail'},
#  1970: {'name': 'bullwhip'},
#  1971: {'name': 'bow'},
#  1972: {'name': 'runed bow'},
#  1973: {'name': 'crude bow'},
#  1974: {'name': 'long bow'},
#  1975: {'name': 'sling'},
#  1976: {'name': 'crossbow'}}

# %%
mapping = {v['name']: v['name'] for v in weapon_glossary.values() if v['name'] in data}

mapping = {
    **mapping, 
    **{
        'knife': 'knife (shito)',
        'lance': 'lance (1)',
        'short sword': 'short sword (wakizashi)',
        'broadsword': 'broadsword (ninja-to)',
        'flail': 'flail (nunchaku)',
    }
}

# %%
[v['name'] for v in weapon_glossary.values() if v['name'] not in mapping]
# Out:
# []

# %%
[k for k in data.keys() if k not in mapping.values()]
# Out:
# ['pick-axe', 'iron hook', 'gray stone', 'unicorn horn']

# %%
weapon_glossary = {
    k: {**v, **data[mapping[v['name']]]} for k, v in weapon_glossary.items()
}
weapon_glossary
# Out:
# {1907: {'name': 'arrow',
#   'skill': 'bow',
#   'cost': 2,
#   'weight': 1,
#   'probability': '55†',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  1908: {'name': 'runed arrow',
#   'skill': 'bow',
#   'cost': 2,
#   'weight': 1,
#   'probability': '20†',
#   'damage_S': 'd7',
#   'damage_L': 'd6',
#   'material': 'wood'},
#  1909: {'name': 'crude arrow',
#   'skill': 'bow',
#   'cost': 2,
#   'weight': 1,
#   'probability': '20†',
#   'damage_S': 'd5',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  1910: {'name': 'silver arrow',
#   'skill': 'bow',
#   'cost': 5,
#   'weight': 1,
#   'probability': '12',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'silver'},
#  1911: {'name': 'bamboo arrow',
#   'skill': 'bow',
#   'cost': 4,
#   'weight': 1,
#   'probability': '15',
#   'damage_S': 'd7',
#   'damage_L': 'd7',
#   'material': 'metal'},
#  1912: {'name': 'crossbow bolt',
#   'skill': 'crossbow',
#   'cost': 2,
#   'weight': 1,
#   'probability': '55†',
#   'damage_S': 'd4+1',
#   'damage_L': 'd6+1',
#   'material': 'iron'},
#  1913: {'name': 'dart',
#   'skill': 'dart',
#   'cost': 2,
#   'weight': 1,
#   'probability': '60†',
#   'damage_S': 'd3',
#   'damage_L': 'd2',
#   'material': 'iron'},
#  1914: {'name': 'throwing star',
#   'skill': 'shuriken',
#   'cost': 5,
#   'weight': 1,
#   'probability': '35',
#   'damage_S': 'd8',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  1915: {'name': 'boomerang',
#   'skill': 'boomerang',
#   'cost': 20,
#   'weight': 5,
#   'probability': '15',
#   'damage_S': 'd9',
#   'damage_L': 'd9',
#   'material': 'wood'},
#  1916: {'name': 'spear',
#   'skill': 'spear',
#   'cost': 3,
#   'weight': 30,
#   'probability': '50†',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1917: {'name': 'runed spear',
#   'skill': 'spear',
#   'cost': 3,
#   'weight': 30,
#   'probability': '10†',
#   'damage_S': 'd7',
#   'damage_L': 'd8',
#   'material': 'wood'},
#  1918: {'name': 'crude spear',
#   'skill': 'spear',
#   'cost': 3,
#   'weight': 30,
#   'probability': '13†',
#   'damage_S': 'd5',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1919: {'name': 'stout spear',
#   'skill': 'spear',
#   'cost': 3,
#   'weight': 35,
#   'probability': '12†',
#   'damage_S': 'd8',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1920: {'name': 'silver spear',
#   'skill': 'spear',
#   'cost': 40,
#   'weight': 36,
#   'probability': '2',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'silver'},
#  1921: {'name': 'throwing spear',
#   'skill': 'spear',
#   'cost': 3,
#   'weight': 20,
#   'probability': '10',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  1922: {'name': 'trident',
#   'skill': 'trident',
#   'cost': 5,
#   'weight': 25,
#   'probability': '8',
#   'damage_S': 'd6+1',
#   'damage_L': '3d4',
#   'material': 'iron'},
#  1923: {'name': 'dagger',
#   'skill': 'dagger',
#   'cost': 4,
#   'weight': 10,
#   'probability': '30',
#   'damage_S': 'd4',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  1924: {'name': 'runed dagger',
#   'skill': 'dagger',
#   'cost': 4,
#   'weight': 10,
#   'probability': '10†',
#   'damage_S': 'd5',
#   'damage_L': 'd3',
#   'material': 'wood'},
#  1925: {'name': 'crude dagger',
#   'skill': 'dagger',
#   'cost': 4,
#   'weight': 10,
#   'probability': '12†',
#   'damage_S': 'd3',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  1926: {'name': 'silver dagger',
#   'skill': 'dagger',
#   'cost': 40,
#   'weight': 12,
#   'probability': '3',
#   'damage_S': 'd4',
#   'damage_L': 'd3',
#   'material': 'silver'},
#  1927: {'name': 'athame',
#   'skill': 'dagger',
#   'cost': 4,
#   'weight': 10,
#   'probability': 'N/A',
#   'damage_S': 'd4',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  1928: {'name': 'scalpel',
#   'skill': 'knife',
#   'cost': 4,
#   'weight': 5,
#   'probability': 'N/A',
#   'damage_S': 'd3',
#   'damage_L': 'd3',
#   'material': 'metal'},
#  1929: {'name': 'knife',
#   'skill': 'knife',
#   'cost': 4,
#   'weight': 5,
#   'probability': '20',
#   'damage_S': 'd3',
#   'damage_L': 'd2',
#   'material': 'iron'},
#  1930: {'name': 'stiletto',
#   'skill': 'knife',
#   'cost': 4,
#   'weight': 5,
#   'probability': '5',
#   'damage_S': 'd3',
#   'damage_L': 'd2',
#   'material': 'iron'},
#  1931: {'name': 'worm tooth',
#   'skill': 'knife',
#   'cost': 2,
#   'weight': 20,
#   'probability': 'N/A',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'undefined'},
#  1932: {'name': 'crysknife',
#   'skill': 'knife',
#   'cost': 100,
#   'weight': 20,
#   'probability': 'N/A',
#   'damage_S': 'd10',
#   'damage_L': 'd10',
#   'material': 'mineral'},
#  1933: {'name': 'axe',
#   'skill': 'axe',
#   'cost': 8,
#   'weight': 60,
#   'probability': '40',
#   'damage_S': 'd6',
#   'damage_L': 'd4',
#   'material': 'iron'},
#  1934: {'name': 'double-headed axe',
#   'skill': 'axe',
#   'cost': 40,
#   'weight': 120,
#   'probability': '10',
#   'damage_S': 'd8+d4',
#   'damage_L': 'd6+2d4',
#   'material': 'iron'},
#  1935: {'name': 'short sword',
#   'skill': 'short sword',
#   'cost': 10,
#   'weight': 30,
#   'probability': '8',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1936: {'name': 'runed short sword',
#   'skill': 'short sword',
#   'cost': 10,
#   'weight': 30,
#   'probability': '2†',
#   'damage_S': 'd8',
#   'damage_L': 'd8',
#   'material': 'wood'},
#  1937: {'name': 'crude short sword',
#   'skill': 'short sword',
#   'cost': 10,
#   'weight': 30,
#   'probability': '3†',
#   'damage_S': 'd5',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1938: {'name': 'broad short sword',
#   'skill': 'short sword',
#   'cost': 10,
#   'weight': 30,
#   'probability': '2†',
#   'damage_S': 'd7',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1939: {'name': 'curved sword',
#   'skill': 'scimitar',
#   'cost': 15,
#   'weight': 40,
#   'probability': '15†',
#   'damage_S': 'd8',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1940: {'name': 'silver saber',
#   'skill': 'saber',
#   'cost': 75,
#   'weight': 40,
#   'probability': '6',
#   'damage_S': 'd8',
#   'damage_L': 'd8',
#   'material': 'silver'},
#  1941: {'name': 'broadsword',
#   'skill': 'broadsword',
#   'cost': 10,
#   'weight': 70,
#   'probability': '8',
#   'damage_S': '2d4',
#   'damage_L': 'd6+1',
#   'material': 'iron'},
#  1942: {'name': 'runed broadsword',
#   'skill': 'broadsword',
#   'cost': 10,
#   'weight': 70,
#   'probability': '4†',
#   'damage_S': 'd6+d4',
#   'damage_L': 'd6+1',
#   'material': 'wood'},
#  1943: {'name': 'long sword',
#   'skill': 'long sword',
#   'cost': 15,
#   'weight': 40,
#   'probability': '50†',
#   'damage_S': 'd8',
#   'damage_L': 'd12',
#   'material': 'iron'},
#  1944: {'name': 'two-handed sword',
#   'skill': 'two-handed sword',
#   'cost': 50,
#   'weight': 150,
#   'probability': '22',
#   'damage_S': 'd12',
#   'damage_L': '3d6',
#   'material': 'iron'},
#  1945: {'name': 'samurai sword',
#   'skill': 'long sword',
#   'cost': 80,
#   'weight': 40,
#   'probability': '4',
#   'damage_S': 'd10',
#   'damage_L': 'd12',
#   'material': 'iron'},
#  1946: {'name': 'long samurai sword',
#   'skill': 'two-handed sword',
#   'cost': 500,
#   'weight': 60,
#   'probability': 'N/A',
#   'damage_S': 'd16',
#   'damage_L': 'd8+2d6',
#   'material': 'metal'},
#  1947: {'name': 'runed broadsword',
#   'skill': 'broadsword',
#   'cost': 10,
#   'weight': 70,
#   'probability': '4†',
#   'damage_S': 'd6+d4',
#   'damage_L': 'd6+1',
#   'material': 'wood'},
#  1948: {'name': 'vulgar polearm',
#   'skill': 'polearms',
#   'cost': 10,
#   'weight': 80,
#   'probability': '5',
#   'damage_S': 'd6',
#   'damage_L': 'd6+1',
#   'material': 'iron'},
#  1949: {'name': 'hilted polearm',
#   'skill': 'polearms',
#   'cost': 6,
#   'weight': 50,
#   'probability': '5',
#   'damage_S': '2d4',
#   'damage_L': '2d4',
#   'material': 'iron'},
#  1950: {'name': 'forked polearm',
#   'skill': 'polearms',
#   'cost': 5,
#   'weight': 50,
#   'probability': '5',
#   'damage_S': 'd6+1',
#   'damage_L': '2d6',
#   'material': 'iron'},
#  1951: {'name': 'single-edged polearm',
#   'skill': 'polearms',
#   'cost': 6,
#   'weight': 75,
#   'probability': '8',
#   'damage_S': 'd6',
#   'damage_L': 'd10',
#   'material': 'iron'},
#  1952: {'name': 'lance',
#   'skill': 'lance',
#   'cost': 10,
#   'weight': 180,
#   'probability': '4',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1953: {'name': 'angled poleaxe',
#   'skill': 'polearms',
#   'cost': 10,
#   'weight': 150,
#   'probability': '8',
#   'damage_S': 'd10',
#   'damage_L': '2d6',
#   'material': 'iron'},
#  1954: {'name': 'long poleaxe',
#   'skill': 'polearms',
#   'cost': 7,
#   'weight': 120,
#   'probability': '4',
#   'damage_S': '2d4',
#   'damage_L': '3d4',
#   'material': 'iron'},
#  1955: {'name': 'pole cleaver',
#   'skill': 'polearms',
#   'cost': 5,
#   'weight': 125,
#   'probability': '4',
#   'damage_S': '2d4',
#   'damage_L': '2d4',
#   'material': 'iron'},
#  1956: {'name': 'broad pick',
#   'skill': 'pick-axe',
#   'cost': 50,
#   'weight': 120,
#   'probability': '13†',
#   'damage_S': 'd12',
#   'damage_L': 'd8+2d6',
#   'material': 'iron'},
#  1957: {'name': 'pole sickle',
#   'skill': 'polearms',
#   'cost': 5,
#   'weight': 60,
#   'probability': '6',
#   'damage_S': 'd6',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1958: {'name': 'pruning hook',
#   'skill': 'polearms',
#   'cost': 5,
#   'weight': 80,
#   'probability': '6',
#   'damage_S': '2d4',
#   'damage_L': 'd8',
#   'material': 'iron'},
#  1959: {'name': 'hooked polearm',
#   'skill': 'polearms',
#   'cost': 7,
#   'weight': 120,
#   'probability': '4',
#   'damage_S': '2d4',
#   'damage_L': 'd10',
#   'material': 'iron'},
#  1960: {'name': 'pronged polearm',
#   'skill': 'polearms',
#   'cost': 7,
#   'weight': 150,
#   'probability': '5',
#   'damage_S': '2d4',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  1961: {'name': 'beaked polearm',
#   'skill': 'polearms',
#   'cost': 8,
#   'weight': 100,
#   'probability': '4',
#   'damage_S': 'd8',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  1962: {'name': 'mace',
#   'skill': 'mace',
#   'cost': 5,
#   'weight': 30,
#   'probability': '40',
#   'damage_S': 'd6+1',
#   'damage_L': 'd6',
#   'material': 'iron'},
#  1963: {'name': 'morning star',
#   'skill': 'morning star',
#   'cost': 10,
#   'weight': 120,
#   'probability': '12',
#   'damage_S': '2d4',
#   'damage_L': 'd6+1',
#   'material': 'iron'},
#  1964: {'name': 'war hammer',
#   'skill': 'hammer',
#   'cost': 5,
#   'weight': 50,
#   'probability': '15',
#   'damage_S': 'd4+1',
#   'damage_L': 'd4',
#   'material': 'iron'},
#  1965: {'name': 'club',
#   'skill': 'club',
#   'cost': 3,
#   'weight': 30,
#   'probability': '12',
#   'damage_S': 'd6',
#   'damage_L': 'd3',
#   'material': 'wood'},
#  1966: {'name': 'rubber hose',
#   'skill': 'whip',
#   'cost': 3,
#   'weight': 20,
#   'probability': 'N/A',
#   'damage_S': 'd4',
#   'damage_L': 'd3',
#   'material': 'plastic'},
#  1967: {'name': 'staff',
#   'skill': 'quarterstaff',
#   'cost': 5,
#   'weight': 40,
#   'probability': '11†',
#   'damage_S': 'd6',
#   'damage_L': 'd6',
#   'material': 'wood'},
#  1968: {'name': 'thonged club',
#   'skill': 'club',
#   'cost': 4,
#   'weight': 15,
#   'probability': '8',
#   'damage_S': 'd6',
#   'damage_L': 'd3',
#   'material': 'iron'},
#  1969: {'name': 'flail',
#   'skill': 'flail',
#   'cost': 4,
#   'weight': 15,
#   'probability': '40',
#   'damage_S': 'd6+1',
#   'damage_L': '2d4',
#   'material': 'iron'},
#  1970: {'name': 'bullwhip',
#   'skill': 'whip',
#   'cost': 4,
#   'weight': 20,
#   'probability': '2',
#   'damage_S': 'd2',
#   'damage_L': '1',
#   'material': 'leather'},
#  1971: {'name': 'bow',
#   'skill': 'bow',
#   'cost': 60,
#   'weight': 30,
#   'probability': '24',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  1972: {'name': 'runed bow',
#   'skill': 'bow',
#   'cost': 60,
#   'weight': 30,
#   'probability': '12†',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  1973: {'name': 'crude bow',
#   'skill': 'bow',
#   'cost': 60,
#   'weight': 30,
#   'probability': '12†',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  1974: {'name': 'long bow',
#   'skill': 'bow',
#   'cost': 60,
#   'weight': 30,
#   'probability': '0',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'},
#  1975: {'name': 'sling',
#   'skill': 'sling',
#   'cost': 20,
#   'weight': 3,
#   'probability': '40',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'leather'},
#  1976: {'name': 'crossbow',
#   'skill': 'crossbow',
#   'cost': 40,
#   'weight': 50,
#   'probability': '45†',
#   'damage_S': 'd2',
#   'damage_L': 'd2',
#   'material': 'wood'}}
